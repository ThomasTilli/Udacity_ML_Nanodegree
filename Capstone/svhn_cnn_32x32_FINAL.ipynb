# %% [markdown]
# # import all modules

# %%
# %matplotlib inline
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

import PIL.Image as Image
import PIL.ImageChops as ImageChops
import PIL.ImageFilter as ImageFilter
import PIL.ImageEnhance as ImageEnhance
import os
import sys
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from collections import OrderedDict
import pandas as pd
import matplotlib

# %% [markdown]
# # load gray scale data from pickle file

# %%
pickle_file = 'SVHN_multin.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset_t = save['train_dataset']
  train_labels_t = save['train_labels']
  valid_dataset_t = save['valid_dataset']
  valid_labels_t = save['valid_labels']
  test_dataset_t = save['test_dataset']
  test_labels_t = save['test_labels']
  del save  
  print('Training set', train_dataset_t.shape, train_labels_t.shape)
  print('Validation set', valid_dataset_t.shape, valid_labels_t.shape)
  print('Test set', test_dataset_t.shape, test_labels_t.shape)
# Out:
# Training set (230070, 32, 32, 1) (230070, 6)
# Validation set (5684, 32, 32, 1) (5684, 6)
# Test set (13068, 32, 32, 1) (13068, 6)

# %% [markdown]
# # Define accuracy function
# How many digits did we  right?

# %%
#how much house numbers are correct -> alle digits of a house number must be correct
def accuracy(predictions, labels,show_details=False,n=100):
 
  if show_details:
        for i in range(0,n):
            print(labels[i],'  ',predictions[i],'  ',np.all(labels[i] == predictions[i]))
  return (100.0 * np.sum(np.all(predictions == labels,axis=1)))/ predictions.shape[0]




#define character level accuracy measuere

def accuracyCharLevel(predictions, labels):

  return (100.0 * np.sum(predictions == labels) / predictions.shape[1] / predictions.shape[0])

print("Success")
# Out:
# Success

# %% [markdown]
# ## Function to display random images with labels

# %%
def display_images(images, labels, rand_indices=None):
    """
        Display random images from a set and return indices so we can match the results
    """
    display_size = 10
    display_per_row = 10
    num_rows = display_size/display_per_row
    if rand_indices is None:
        rand_indices = np.random.randint(0, images.shape[0], size=display_size)
    row_size = 20
    col_size = 20

    fig = plt.figure(figsize=(20, 20))
    for idx in range(len(rand_indices)):
        orig_idx = rand_indices[idx]
        display_row_idx = int(idx/display_per_row) + 1
        display_col_idx = idx%display_per_row +1
        a=fig.add_subplot(display_row_idx, display_per_row, display_col_idx, frameon=False)
        a.get_yaxis().set_visible(False)
        a.get_xaxis().set_visible(False)
        a.imshow(images[orig_idx,:,:,0], cmap="Greys_r")
        
        house_num = ''
        for k in np.arange(labels[orig_idx,0]):
            house_num += str(labels[orig_idx,k+1])
      
        a.set_title(house_num)
    return rand_indices

# %% [markdown]
# ## Show some preprocessed images from training and test data sets with labels

# %%
display_images(train_dataset_t, train_labels_t)
display_images(test_dataset_t, test_labels_t)
# Out:
# array([ 3499,  3648,  3733, 12164,  8033, 12042,  5448,  6656, 10139,  2221])

# %% [markdown]
# # Data augmentation
# ## Helper functions to convert images from numpy to PIL and back

# %%
def array2image(fa):
   
    return Image.frombytes("F", (fa.shape[1], fa.shape[0]), fa.tostring())
   

def image2Array(img):    
    ar=np.array(img)*1.0
    return ar

# %%
#some test
idx=0
npim=train_dataset_t[idx,:,:,0]

im=array2image(npim).convert("L")
plt.imshow(im,cmap="Greys_r")


npimg=image2Array(im)
print(npimg-npim)
# Out:
# [[-0.71279907 -0.90850067 -0.20739746 ..., -0.22570038 -0.51390076
#   -0.04090118]
#  [-0.31069946 -0.60939789 -0.20709991 ..., -0.22619629 -0.5141983
#   -0.92710114]
#  [-0.31060028 -0.13639832 -0.62000275 ..., -0.33940125 -0.5141983
#   -0.62850189]
#  ...,
#  [-0.53890228 -0.83779907 -0.23950195 ..., -0.40570068 -0.13459778
#   -0.73220062]
#  [-0.13680267 -0.13659668 -0.31030273 ..., -0.36139679 -0.02010345
#   -0.20500183]
#  [-0.13690186 -0.73459625 -0.79460144 ..., -0.36129761 -0.79180145
#   -0.97669983]]

# %% [markdown]
# ## Augment one image

# %%
from time import time
def generateAugmentedData(npimg,label,images,labels,n=1):
  
    #first append original image
    images.append(npimg)
    labels.append(label)
    im=array2image(npimg).convert("L")
    # do n random rotations 
    for i in range(0,n):
        rot=np.random.uniform(-20,20)
        img=im.rotate(rot,Image.BILINEAR)
        images.append(image2Array(img))
        labels.append(label)
    #do n random movements    more aggresive
    for i in range(0,n):
        dx=np.random.randint(-10,10)
        dy=np.random.randint(-10,10)
        img=ImageChops.offset(im,dx,dy)
        images.append(image2Array(img))
        labels.append(label)
    #do n random sharpness operations more aggresive
    enhancer = ImageEnhance.Sharpness(im)
    for i in range(0,n):
        en=np.random.uniform(-4,4)
        img=enhancer.enhance(en)
        images.append(image2Array(img))
        labels.append(label)
    
   #do n random brightness operations more aggresive
    enhancer = ImageEnhance.Brightness(im) 
    for i in range(0,n):
        en=np.random.uniform(0.01,3)
        img=enhancer.enhance(en)
        images.append(image2Array(img))
        labels.append(label)
    #do n random contrast operations
    enhancer = ImageEnhance.Contrast(im)
    for i in range(0,n):
        en=np.random.uniform(-2,3)
        img=enhancer.enhance(en)
        images.append(image2Array(img))
        labels.append(label)

 
    return images,labels

# %%
#some tests
idx=0
print (len(train_dataset_t))
npim=train_dataset_t[idx,:,:,0]
print(np.mean(npim))
mean=np.mean(npim)
imn=train_dataset_t[idx]-mean
print(np.sum(imn)/1024.0)
print(np.mean(train_dataset_t[idx]))
t0=time()
images=[]
labels=[]
for idx in range(0,1000):
    npim=train_dataset_t[idx,:,:,0]
    images,labels=generateAugmentedData(npim, train_labels_t[idx],images,labels) 

dataset = np.ndarray([len(images),32,32,1], dtype='float32')
for idx in range(0,len(images)):
    image=images[idx]
  #  print(image[:,:,np.newaxis].shape)
  #  im=image[:,:,np.newaxis]
  
    dataset[idx,:,:,:] = image[:,:,np.newaxis]
print ("time used s",time()-t0)    
print(len(dataset))
ind=range(0,10)
display_images(dataset, np.array(labels),ind)   

sum=0.0
for idx in range(0,len(images)):
    image= dataset[idx,:,:,:]
    sum+=np.sum(image)/1024.0
print (sum/len(images))    
mean=np.mean(dataset)
std=np.std(dataset)
display_images((dataset-mean)/std, np.array(labels),ind)
# Out:
# 230070
# 75.7368
# 2.98023223877e-06
# 75.7368
# time used s 0.605360031128
# 6000
# 112.383940122
# xrange(10)

# %%
def generateAugmentedDataSet(image_data,image_label,n=2):
    init=True
    labels=[]
    len_data=len(image_data)
   
    for idx in range(0,len_data):    
        if idx%20000==0:
            print(idx)
        npim=image_data[idx,:,:,0]
        images=[]
      
        images,labels=generateAugmentedData(npim, image_label[idx],images,labels,n) 
        lenIm=len(images)
       
        if init==True:
            print(lenIm)
            img_dataset = np.ndarray([lenIm*len_data,32,32,1], dtype='float32')
            init=False
        for i in range(0,lenIm):
            image=images[i]
            img_dataset[idx*lenIm+i,:,:,:] = image[:,:,np.newaxis]
    img_lables=np.array(labels)   
    del labels
    return img_dataset, img_lables

# %%
train_dataset_augm,train_labels_augm=generateAugmentedDataSet(train_dataset_t, train_labels_t,8)   #make more!

display_images(train_dataset_augm, train_labels_augm)   
valid_dataset_augm, valid_labels_augm=generateAugmentedDataSet(valid_dataset_t, valid_labels_t,1) 
display_images(valid_dataset_augm, valid_labels_augm)  

test_dataset_augm, test_labels_augm=generateAugmentedDataSet(test_dataset_t, test_labels_t,1) 
display_images(test_dataset_augm, test_labels_augm)  

print(len(train_dataset_t),len(train_dataset_augm))
print(len(valid_dataset_t),len(valid_dataset_augm))
print(len(test_dataset_t),len(test_dataset_augm))
# Out:
# 0
# 41
# 20000
# 40000
# 60000
# 80000
# 100000
# 120000
# 140000
# 160000
# 180000
# 200000
# 220000
# 0
# 6
# 0
# 6
# 230070 9432870
# 5684 34104
# 13068 78408

# %% [markdown]
# ## Shuffle data sets

# %%
train_dataset = train_dataset_t
train_labels = train_labels_t
valid_dataset = valid_dataset_t
valid_labels = valid_labels_t
test_dataset = test_dataset_t
test_labels = test_labels_t

train_dataset = train_dataset_augm
train_labels = train_labels_augm
#valid_dataset = valid_dataset_augm
#valid_labels = valid_labels_augm
#test_dataset = test_dataset_augm
#test_labels = test_labels_augm

train_dataset,train_labels=shuffle(train_dataset,train_labels)
display_images(train_dataset, train_labels) 

valid_dataset, valid_labels=shuffle(valid_dataset, valid_labels)
display_images(valid_dataset, valid_labels) 

test_dataset, test_labels=shuffle(test_dataset, test_labels)
display_images(test_dataset, test_labels)
# Out:
# array([10819, 11342,  2994,    47,  9435,  3714,  6519,  8802, 12082,  9013])

# %% [markdown]
# ## normalize the images by mean and standard deviation per image

# %%
def normalizeImages(dataset):
    for idx in range (0,len(dataset)):
        im= dataset[idx,:,:,0]
        mean=np.mean(im, dtype=np.float64)
        std=np.std(im, dtype=np.float64)
        if std<0.001:
            std=1.0
        im=(im-mean)/std
        dataset[idx,:,:,0]=im

# %%
normalizeImages(train_dataset)
normalizeImages(valid_dataset)
normalizeImages(test_dataset)
print (train_dataset.shape)
print (valid_dataset.shape)
print (test_dataset.shape)
print("normalization done")
# Out:
# (9432870, 32, 32, 1)
# (5684, 32, 32, 1)
# (13068, 32, 32, 1)
# normalization done

# %% [markdown]
# ## plot accuracy and loss

# %%
def plot_results(acc_train,acc_valid,losses,ymin=80,ymax=100):
    matplotlib.rc('xtick', labelsize=14) 
    matplotlib.rc('ytick', labelsize=14) 
    matplotlib.rcParams.update({'font.size': 18})
    steps=losses.keys()
    loss=losses.values()
   
    dflosses=pd.DataFrame(losses.values(),columns=['Loss'],index=steps)
    dflosses.index.names=['Steps']
    dflosses.plot(figsize=(15,10),ylim=(0.0,2.0),title="Loss")
    dfacc=pd.DataFrame([acc_train.values(),acc_valid.values()])

    dfacc=dfacc.transpose()
    dfacc.columns=['Train Accurary','Validation Accurary']
    dfacc.index=steps
    dfacc.index.names=['Steps']
    dfacc.plot(figsize=(15,10),ylim=(ymin,ymax),title="Accuracy")

# %% [markdown]
# # Convolution Network

# %% [markdown]
# ## Helper functions

# %%
# Helper functions
def create_weight_conv(name,shape):
    return tf.get_variable(name, shape,initializer=tf.contrib.layers.xavier_initializer_conv2d())

def create_weight(name,shape):
    return tf.get_variable(name, shape,initializer=tf.contrib.layers.xavier_initializer())

def create_bias(name,shape):
    return tf.Variable(tf.constant(1.0, shape=shape),name=name)


def create_conv_layer(name,data, weights,padding,conv_stride):
    return tf.nn.conv2d(data, weights, [1, conv_stride, conv_stride, 1], padding)

def create_pool_layer(name,data,pool_window_size,padding,pool_stride):
    return tf.nn.max_pool(data, pool_window_size, pool_stride, padding)

def get_conv_shape(data_shape, weights_shape,padding,conv_stride):
    if padding == 'VALID':
        new_height = int(np.ceil((1.0*(data_shape[1] - weights_shape[0] + 1)) / conv_stride))
        new_width = int(np.ceil((1.0*(data_shape[2] - weights_shape[1] + 1)) / conv_stride))
    else:
        new_height = int(np.ceil(1.0*data_shape[1]) / conv_stride)
        new_width = int(np.ceil(1.0*data_shape[2] / conv_stride))
    return (data_shape[0], new_height, new_width, weights_shape[3])

def get_pool_shape(data_shape,pool_stride):
    new_height = int(np.ceil(1.0*data_shape[1] / pool_stride[1]))
    new_width = int(np.ceil(1.0*data_shape[2] / pool_stride[2]))
    return (data_shape[0], new_height, new_width, data_shape[3])

# %% [markdown]
# # Add a second fully connected layer, local response normalization before relu,  dropout layers in all conv ¶
#
# Conv ->Conv ->MaxPool-->conv->conv ->maxpool->conv->fully connected1 -> fully connected2 ->logits

# %%
def deepCNN2(datasets,topology_params, learning_params,model_name,num_channels=1):
    """Construct Model"""
    print ("deep CNN five conv layers two fully connected layers, lrn before relu")
    image_size = 32
    num_labels = 11 # 0-9, + blank 
    
    conv_stride = 1
    pool_window_size = [1, 2, 2, 1]
    pool_stride = [1, 2, 2, 1]
    padconv = 'SAME'
    padpool = 'SAME'
    patch_size5=5
    patch_size3=3
    train_dataset = datasets['train_dataset']
    train_labels = datasets['train_labels']
    valid_dataset = datasets['valid_dataset']
    valid_labels = datasets['valid_labels']
    test_dataset = datasets['test_dataset']
    test_labels = datasets['test_labels']
    

    depth1 = topology_params['depth1']
    depth2 = topology_params['depth2']
    depth3 = topology_params['depth3']
    depth4 = topology_params['depth4']
    depth5 = topology_params['depth5']
    patch_size1=topology_params['patch_size1']
    patch_size2=topology_params['patch_size2']

 
    num_hidden1 = topology_params['num_hidden1']
    num_hidden2 = topology_params['num_hidden2']
        
    num_steps=learning_params['num_steps']
    batch_size=learning_params['batch_size']
    learning_rate=learning_params['learning_rate']
     
    shape = [batch_size, image_size, image_size, num_channels]

    graph = tf.Graph()
    losses=OrderedDict()
    acc_train=OrderedDict()
    acc_valid=OrderedDict()
  
    
    with  graph.as_default():
      #define weights and biases
      # Input data.
      tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
      tf_train_labels = tf.placeholder(tf.int32, shape=(batch_size, 6))
      tf_valid_dataset =  tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
      tf_valid_labels = tf.placeholder(tf.int32, shape=(batch_size, 6))
      tf_test_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
      tf_test_labels = tf.placeholder(tf.int32, shape=(batch_size, 6))

      # Convolution layers.
      # First convolution layer
      conv_1_weights = create_weight_conv("W1",shape=[patch_size1, patch_size1, num_channels, depth1])
      conv_1_biases = create_bias('B1',shape=[depth1])     
      conv_1_shape = get_conv_shape(tf_train_dataset.get_shape().as_list(),conv_1_weights.get_shape().as_list(),\
                                    padconv,conv_stride)    
    
      print("cv1",conv_1_shape)
  
      # Second convolution layer 
      conv_2_weights = create_weight_conv("W2",shape=[patch_size1, patch_size1, depth1, depth2])
      conv_2_biases = create_bias('B2',shape=[depth2])
      conv_2_shape = get_conv_shape(conv_1_shape, conv_2_weights.get_shape().as_list(),padconv,conv_stride)
      pool_2_shape = get_pool_shape(conv_2_shape,pool_stride)
    
      print("cv2",conv_2_shape)
      print("p2",pool_2_shape)
    
    
      # Third convolution layer
      conv_3_weights = create_weight_conv("W3",shape=[patch_size2, patch_size2, depth2, depth3])
      conv_3_biases = create_bias('B3',shape=[depth3])     
      conv_3_shape = get_conv_shape(pool_2_shape,conv_3_weights.get_shape().as_list(),\
                                    padconv,conv_stride)    
    
      print("cv3",conv_3_shape)
  
      # Fourth convolution layer 
      conv_4_weights = create_weight_conv("W4",shape=[patch_size2, patch_size2, depth3, depth4])
      conv_4_biases = create_bias('B4',shape=[depth4])
      conv_4_shape = get_conv_shape(conv_3_shape, conv_4_weights.get_shape().as_list(),padconv,conv_stride)
      pool_4_shape = get_pool_shape(conv_4_shape,pool_stride)
    
      print("cv4",conv_4_shape)
      print("p4",pool_4_shape)
    
     # Fifth convolution layer 
      conv_5_weights = create_weight_conv("W5",shape=[patch_size2, patch_size2, depth4, num_hidden1])
      conv_5_biases = create_bias('B5',shape=[num_hidden1])
      conv_5_shape = get_conv_shape(pool_4_shape, conv_5_weights.get_shape().as_list(),padconv,conv_stride)
      pool_5_shape = get_pool_shape(conv_5_shape,pool_stride)
      
      print("cv5",conv_5_shape)
      print("p5",pool_5_shape)
    
      #Frist fully connected layer
      final_shape=pool_5_shape
      final_flat = final_shape[1] * final_shape[2] * final_shape[3]
      print("ff",final_flat)
    
      #second fully connected layer
      weights_full1 = create_weight("FW1",(final_flat, num_hidden1))
      biases_full1 = create_bias("FB1",(num_hidden1,))
  

      weights_full2 = create_weight("FW2",(num_hidden1, num_hidden2))
      biases_full2 = create_bias("FB2",(num_hidden2,))
        
      # Hidden layer
      s0_w = create_weight("WHS0",(num_hidden2, num_labels))
      s1_w = create_weight("WHS1",(num_hidden2, num_labels))
      s2_w = create_weight("WHS2",(num_hidden2, num_labels))
      s3_w = create_weight("WHS3",(num_hidden2, num_labels))
      s4_w = create_weight("WHS4",(num_hidden2, num_labels))
      s0_b = create_bias("BHS0",(num_labels,))
      s1_b = create_bias("BHS1",(num_labels,))
      s2_b = create_bias("BHS2",(num_labels,))
      s3_b = create_bias("BHS3",(num_labels,))
      s4_b = create_bias("BHS4",(num_labels,))   
    

      # CNN model
      def model(data, keep_prob):
     #   print ("keep prob",keep_prob)
        conv1 = create_conv_layer('C1',data, conv_1_weights,padconv,conv_stride) + conv_1_biases
        lrn1 = tf.nn.local_response_normalization(conv1)
        lrn1=tf.nn.dropout(lrn1, keep_prob)
        
        conv2 = create_conv_layer('C2',tf.nn.relu(lrn1), conv_2_weights,padconv,conv_stride) + conv_2_biases
        lrn2 = tf.nn.local_response_normalization(conv2)
        pool2 = create_pool_layer('P2',tf.nn.relu(lrn2),pool_window_size,padpool,pool_stride)
        pool2=tf.nn.dropout(pool2, keep_prob)
        
        conv3 = create_conv_layer('C3',pool2, conv_3_weights,padconv,conv_stride) + conv_3_biases
        lrn3 = tf.nn.local_response_normalization(conv3)
        lrn3=tf.nn.dropout(lrn3, keep_prob)
        
        conv4 = create_conv_layer('C4',tf.nn.relu(lrn3), conv_4_weights,padconv,conv_stride) + conv_4_biases
        lrn4 = tf.nn.local_response_normalization(conv4)
        pool4 = create_pool_layer('P4',tf.nn.relu(lrn4),pool_window_size,padpool,pool_stride)
        pool4=tf.nn.dropout(pool4, keep_prob)
        
        conv5 = create_conv_layer('C5',pool4, conv_5_weights,padconv,conv_stride) + conv_5_biases
        lrn5 = tf.nn.local_response_normalization(conv5)
        pool5 = create_pool_layer('P5',tf.nn.relu(lrn5),pool_window_size,padpool,pool_stride)
        pool5=tf.nn.dropout(pool5, keep_prob)
        last=pool5
      
        shape = last.get_shape().as_list() 
     #   print (shape)
        reshape = tf.reshape(last, [shape[0], final_flat])
        # First fully connected layer
        full1 = tf.nn.relu(tf.matmul(reshape, weights_full1) + biases_full1)
        final1 = tf.nn.dropout(full1, keep_prob)
       
       # Second fully connected layer
        full2 = tf.nn.relu(tf.matmul(final1, weights_full2) + biases_full2)
        final2 = tf.nn.dropout(full2, keep_prob)
        
        #logits
        logits0 = tf.matmul(final2, s0_w) + s0_b  #lenght of house number
        logits1 = tf.matmul(final2, s1_w) + s1_b  #1. digit
        logits2 = tf.matmul(final2, s2_w) + s2_b  #2. digit
        logits3 = tf.matmul(final2, s3_w) + s3_b  #3. digit
        logits4 = tf.matmul(final2, s4_w) + s4_b  #4. digit
        return [logits0, logits1, logits2, logits3, logits4]

      # Training computation.
      [logits0, logits1, logits2, logits3, logits4] = model(tf_train_dataset, 0.5)
      # Define loss function.
     
      loss = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits0, tf_train_labels[:,0])) +\
    tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits1, tf_train_labels[:,1])) +\
    tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits2, tf_train_labels[:,2])) +\
    tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits3, tf_train_labels[:,3])) +\
    tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits4, tf_train_labels[:,4]))

      # Optimizer.
      global_step = tf.Variable(0)
      #learning rate with exponential decay.
  #    learning_rate = tf.train.exponential_decay(learning_rate, global_step, 20000, 0.95) 
 
      
      optimizer = tf.train.AdamOptimizer(learning_rate).minimize(loss)
    
      # Predictions for the training, validation, and test data.
      [logits0, logits1, logits2, logits3, logits4] = model(tf_train_dataset, 1.0)
      train_prediction = tf.pack([tf.nn.softmax(logits0),\
                                 tf.nn.softmax(logits1),\
                                 tf.nn.softmax(logits2),\
                                 tf.nn.softmax(logits3),\
                                 tf.nn.softmax(logits4)])
    
      [logits0, logits1, logits2, logits3, logits4] = model(tf_valid_dataset, 1.0)
      valid_prediction = tf.pack([tf.nn.softmax(logits0),\
                                 tf.nn.softmax(logits1),\
                                 tf.nn.softmax(logits2),\
                                 tf.nn.softmax(logits3),\
                                 tf.nn.softmax(logits4)])   
    
      [logits0, logits1, logits2, logits3, logits4] = model(tf_test_dataset, 1.0)   
      test_prediction = tf.pack([tf.nn.softmax(logits0),\
                                 tf.nn.softmax(logits1),\
                                 tf.nn.softmax(logits2),\
                                 tf.nn.softmax(logits3),\
                                 tf.nn.softmax(logits4)])   

      saver = tf.train.Saver()



    with tf.Session(graph=graph) as session:
      tf.initialize_all_variables().run()  

      #"to be used after first iteration"
      #saver.restore(session, model_name)
      #print("Model restored.") 

      print('Initialized')
      for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size),:]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run(
          [optimizer, loss, train_prediction], feed_dict=feed_dict)

       
        if (step % 2500 == 0): 
          
            trainacc= accuracy(np.argmax(predictions, 2).T, batch_labels[:,0:5])
            acc_train[step]=trainacc   
            val_preds_total = np.ndarray((valid_labels.shape[0],valid_labels.shape[1]-1))
            for k in range(int(np.floor(valid_labels.shape[0] / batch_size))):
                batch_start_val = batch_size * k
                batch_end_val = batch_start_val + batch_size
                batch_D_val = valid_dataset[batch_start_val:batch_end_val,:,:,:]
                batch_L_val = valid_labels[batch_start_val:batch_end_val,:] 
                feed_dict = {tf_valid_dataset: batch_D_val, tf_valid_labels: batch_L_val}
                val_preds_total[batch_start_val:batch_end_val,:] = np.argmax(session.run(valid_prediction, feed_dict), 2).T
           
            val_preds_eval = val_preds_total   
          #  pred_val=valid_prediction.eval()
         #   valacc=accuracy(np.argmax(pred_val, 2).T, valid_labels[:,0:5])
            valacc=accuracy(val_preds_eval,valid_labels[:,0:5])
           
            acc_valid[step]=valacc
            
            valaccChar=accuracyCharLevel(val_preds_eval, valid_labels[:,0:5])
            losses[step]=l
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.2f%%' % trainacc)
            print('Validation accuracy: %.2f%%' % valacc)
            print('Validation accuracy character level: %.2f%%' % valaccChar)  
           
            
   
      test_labels_shape=test_labels.shape  
      test_preds_total = np.ndarray((test_labels.shape[0],test_labels.shape[1]-1))
      for j in range(int(np.floor(test_labels.shape[0] / batch_size))):
            batch_start_test = batch_size * j
            batch_end_test = batch_start_test + batch_size
            batch_D_test = test_dataset[batch_start_test:batch_end_test,:,:,:]
            batch_L_test = test_labels[batch_start_test:batch_end_test,:]                
            feed_dict = {tf_test_dataset: batch_D_test, tf_test_labels: batch_L_test}
            test_preds_total[batch_start_test:batch_end_test,:] = np.argmax(session.run(test_prediction, feed_dict), 2).T
      
      test_preds_eval = test_preds_total     
      testacc=accuracy(test_preds_total, test_labels[:,0:5],show_details=True,n=100)
      testaccChar=accuracyCharLevel(test_preds_total, test_labels[:,0:5])
      print('====> Test accuracy character level: %.2f%%' % testaccChar)  
  
      print('====> Test accuracy: %.2f%%' % testacc)
      save_path = saver.save(session, model_name)
      print("Model saved in file: %s" % save_path)
      return  acc_train,acc_valid,losses

# %%
datasets={}
topology_params={}
learning_params={}
learning_params={}


datasets['train_dataset']=train_dataset
datasets['train_labels']=train_labels
datasets['valid_dataset']=valid_dataset
datasets['valid_labels']=valid_labels
datasets['test_dataset']=test_dataset
datasets['test_labels']=test_labels


model_name="CNN_multi_deep_ful2_32x32BN.ckpt"


# larger dataaugmentation
#lrn
topology_params['patch_size1']=5
topology_params['patch_size2']=5
topology_params['depth1']=16*2
topology_params['depth2']=32*4
topology_params['depth3']=64*4
topology_params['depth4']=64*4
topology_params['depth5']=64*4

topology_params['num_hidden1']=64*12
topology_params['num_hidden2']=64*12

#dropout 0.5 more data augmentation
learning_params['batch_size']=256
learning_params['num_steps']=1000001 
# more data augmentatuion
#====> Test accuracy character level: 98.54%!!
#====> Test accuracy: 95.91% !!
# mild overfitting
# about 5 days on 2 Titan X Pascal
# model renamed "CNN_multi_deep_ful2_32x32BN95_91.ckpt"

topology_params['patch_size1']=5
topology_params['patch_size2']=5
topology_params['depth1']=16*2
topology_params['depth2']=32*4
topology_params['depth3']=64*4
topology_params['depth4']=64*6
topology_params['depth5']=64*6

topology_params['num_hidden1']=64*14
topology_params['num_hidden2']=64*14
learning_params['batch_size']=256
learning_params['num_steps']=500001 
learning_params['learning_rate']=1.0E-4
#====> Test accuracy character level: 98.46%
#====> Test accuracy: 95.55%

    
topology_params['patch_size1']=5
topology_params['patch_size2']=5
topology_params['depth1']=16*4
topology_params['depth2']=32*4
topology_params['depth3']=64*4
topology_params['depth4']=64*4
topology_params['depth5']=64*4

topology_params['num_hidden1']=64*12
topology_params['num_hidden2']=64*12

#dropout 0.5 more data augmentation
learning_params['batch_size']=256
learning_params['num_steps']=1000001 
# about one week on Titan X Pascal
#====> Test accuracy character level: 98.55%
#====> Test accuracy: 96.00%
#model renamed to "CNN_multi_deep_ful2_32x32BN96_00.ckpt"
acc_train,acc_valid,losses=deepCNN2(datasets,topology_params, learning_params,model_name)
# Out:
# deep CNN five conv layers two fully connected layers, lrn before relu
# cv1 (256, 32, 32, 64)
# cv2 (256, 32, 32, 128)
# p2 (256, 16, 16, 128)
# cv3 (256, 16, 16, 256)
# cv4 (256, 16, 16, 256)
# p4 (256, 8, 8, 256)
# cv5 (256, 8, 8, 768)
# p5 (256, 4, 4, 768)
# ff 12288
# WARNING:tensorflow:From <ipython-input-17-e5f9c48331a2>:200 in deepCNN2.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Minibatch loss at step 0: 33.300163
# Minibatch accuracy: 0.00%
# Validation accuracy: 0.00%
# Validation accuracy character level: 42.13%
# Minibatch loss at step 2500: 7.844503
# Minibatch accuracy: 0.00%
# Validation accuracy: 0.00%
# Validation accuracy character level: 42.53%
# Minibatch loss at step 5000: 7.983840
# Minibatch accuracy: 0.00%
# Validation accuracy: 0.00%
# Validation accuracy character level: 42.56%
# Minibatch loss at step 7500: 7.743005
# Minibatch accuracy: 0.00%
# Validation accuracy: 0.00%
# Validation accuracy character level: 42.53%
# Minibatch loss at step 10000: 7.881970
# Minibatch accuracy: 0.00%
# Validation accuracy: 0.00%
# Validation accuracy character level: 42.56%
# Minibatch loss at step 12500: 5.083094
# Minibatch accuracy: 16.80%
# Validation accuracy: 21.08%
# Validation accuracy character level: 72.71%
# Minibatch loss at step 15000: 3.161891
# Minibatch accuracy: 53.91%
# Validation accuracy: 63.39%
# Validation accuracy character level: 88.23%
# Minibatch loss at step 17500: 2.616055
# Minibatch accuracy: 64.45%
# Validation accuracy: 75.35%
# Validation accuracy character level: 92.07%
# Minibatch loss at step 20000: 2.059371
# Minibatch accuracy: 68.75%
# Validation accuracy: 80.70%
# Validation accuracy character level: 93.83%
# Minibatch loss at step 22500: 1.620580
# Minibatch accuracy: 77.34%
# Validation accuracy: 83.88%
# Validation accuracy character level: 94.70%
# Minibatch loss at step 25000: 1.669441
# Minibatch accuracy: 81.64%
# Validation accuracy: 86.08%
# Validation accuracy character level: 95.25%
# Minibatch loss at step 27500: 1.440318
# Minibatch accuracy: 83.98%
# Validation accuracy: 87.53%
# Validation accuracy character level: 95.64%
# Minibatch loss at step 30000: 1.382520
# Minibatch accuracy: 85.16%
# Validation accuracy: 87.95%
# Validation accuracy character level: 95.78%
# Minibatch loss at step 32500: 1.193040
# Minibatch accuracy: 87.89%
# Validation accuracy: 88.85%
# Validation accuracy character level: 96.03%
# Minibatch loss at step 35000: 1.053408
# Minibatch accuracy: 90.23%
# Validation accuracy: 89.30%
# Validation accuracy character level: 96.19%
# Minibatch loss at step 37500: 0.862146
# Minibatch accuracy: 90.62%
# Validation accuracy: 90.41%
# Validation accuracy character level: 96.36%
# Minibatch loss at step 40000: 0.967577
# Minibatch accuracy: 89.84%
# Validation accuracy: 90.17%
# Validation accuracy character level: 96.41%
# Minibatch loss at step 42500: 0.726639
# Minibatch accuracy: 89.06%
# Validation accuracy: 90.48%
# Validation accuracy character level: 96.45%
# Minibatch loss at step 45000: 0.854339
# Minibatch accuracy: 89.06%
# Validation accuracy: 90.48%
# Validation accuracy character level: 96.47%
# Minibatch loss at step 47500: 0.789188
# Minibatch accuracy: 90.62%
# Validation accuracy: 90.82%
# Validation accuracy character level: 96.48%
# Minibatch loss at step 50000: 0.707924
# Minibatch accuracy: 93.36%
# Validation accuracy: 90.94%
# Validation accuracy character level: 96.63%
# Minibatch loss at step 52500: 0.812281
# Minibatch accuracy: 91.02%
# Validation accuracy: 90.87%
# Validation accuracy character level: 96.51%
# Minibatch loss at step 55000: 0.724770
# Minibatch accuracy: 92.58%
# Validation accuracy: 91.29%
# Validation accuracy character level: 96.71%
# Minibatch loss at step 57500: 1.030101
# Minibatch accuracy: 91.02%
# Validation accuracy: 91.50%
# Validation accuracy character level: 96.71%
# Minibatch loss at step 60000: 0.774909
# Minibatch accuracy: 93.36%
# Validation accuracy: 91.73%
# Validation accuracy character level: 96.77%
# Minibatch loss at step 62500: 0.628928
# Minibatch accuracy: 93.36%
# Validation accuracy: 91.89%
# Validation accuracy character level: 96.79%
# Minibatch loss at step 65000: 0.761935
# Minibatch accuracy: 92.19%
# Validation accuracy: 91.75%
# Validation accuracy character level: 96.82%
# Minibatch loss at step 67500: 0.515844
# Minibatch accuracy: 93.75%
# Validation accuracy: 91.57%
# Validation accuracy character level: 96.75%
# Minibatch loss at step 70000: 0.696694
# Minibatch accuracy: 93.36%
# Validation accuracy: 91.85%
# Validation accuracy character level: 96.83%
# Minibatch loss at step 72500: 0.647826
# Minibatch accuracy: 92.97%
# Validation accuracy: 92.19%
# Validation accuracy character level: 96.89%
# Minibatch loss at step 75000: 0.588027
# Minibatch accuracy: 93.75%
# Validation accuracy: 92.00%
# Validation accuracy character level: 96.84%
# Minibatch loss at step 77500: 0.491442
# Minibatch accuracy: 95.31%
# Validation accuracy: 92.26%
# Validation accuracy character level: 96.87%
# Minibatch loss at step 80000: 0.548745
# Minibatch accuracy: 95.31%
# Validation accuracy: 92.31%
# Validation accuracy character level: 96.99%
# Minibatch loss at step 82500: 0.574267
# Minibatch accuracy: 95.70%
# Validation accuracy: 92.01%
# Validation accuracy character level: 96.87%
# Minibatch loss at step 85000: 0.437726
# Minibatch accuracy: 95.31%
# Validation accuracy: 92.61%
# Validation accuracy character level: 97.00%
# Minibatch loss at step 87500: 0.547204
# Minibatch accuracy: 94.14%
# Validation accuracy: 92.35%
# Validation accuracy character level: 96.92%
# Minibatch loss at step 90000: 0.663498
# Minibatch accuracy: 92.58%
# Validation accuracy: 92.45%
# Validation accuracy character level: 97.04%
# Minibatch loss at step 92500: 0.385649
# Minibatch accuracy: 96.48%
# Validation accuracy: 92.66%
# Validation accuracy character level: 97.03%
# Minibatch loss at step 95000: 0.369628
# Minibatch accuracy: 95.70%
# Validation accuracy: 92.59%
# Validation accuracy character level: 97.02%
# Minibatch loss at step 97500: 0.521637
# Minibatch accuracy: 95.31%
# Validation accuracy: 92.61%
# Validation accuracy character level: 97.02%
# Minibatch loss at step 100000: 0.509532
# Minibatch accuracy: 94.53%
# Validation accuracy: 92.63%
# Validation accuracy character level: 97.03%
# Minibatch loss at step 102500: 0.678978
# Minibatch accuracy: 92.58%
# Validation accuracy: 92.70%
# Validation accuracy character level: 97.04%
# Minibatch loss at step 105000: 0.483741
# Minibatch accuracy: 96.48%
# Validation accuracy: 92.51%
# Validation accuracy character level: 97.02%
# Minibatch loss at step 107500: 0.490017
# Minibatch accuracy: 96.09%
# Validation accuracy: 92.79%
# Validation accuracy character level: 97.07%
# Minibatch loss at step 110000: 0.450187
# Minibatch accuracy: 94.53%
# Validation accuracy: 92.63%
# Validation accuracy character level: 97.08%
# Minibatch loss at step 112500: 0.495633
# Minibatch accuracy: 96.09%
# Validation accuracy: 92.72%
# Validation accuracy character level: 97.08%
# Minibatch loss at step 115000: 0.632306
# Minibatch accuracy: 94.92%
# Validation accuracy: 92.77%
# Validation accuracy character level: 97.11%
# Minibatch loss at step 117500: 0.636620
# Minibatch accuracy: 94.14%
# Validation accuracy: 92.96%
# Validation accuracy character level: 97.11%
# Minibatch loss at step 120000: 0.410764
# Minibatch accuracy: 97.27%
# Validation accuracy: 92.93%
# Validation accuracy character level: 97.11%
# Minibatch loss at step 122500: 0.311983
# Minibatch accuracy: 98.05%
# Validation accuracy: 92.89%
# Validation accuracy character level: 97.10%
# Minibatch loss at step 125000: 0.359653
# Minibatch accuracy: 97.66%
# Validation accuracy: 92.91%
# Validation accuracy character level: 97.11%
# Minibatch loss at step 127500: 0.460148
# Minibatch accuracy: 93.75%
# Validation accuracy: 92.95%
# Validation accuracy character level: 97.07%
# Minibatch loss at step 130000: 0.537810
# Minibatch accuracy: 94.14%
# Validation accuracy: 92.82%
# Validation accuracy character level: 97.10%
# Minibatch loss at step 132500: 0.628890
# Minibatch accuracy: 92.19%
# Validation accuracy: 92.98%
# Validation accuracy character level: 97.10%
# Minibatch loss at step 135000: 0.418269
# Minibatch accuracy: 98.44%
# Validation accuracy: 92.95%
# Validation accuracy character level: 97.13%
# Minibatch loss at step 137500: 0.560299
# Minibatch accuracy: 93.36%
# Validation accuracy: 92.65%
# Validation accuracy character level: 97.03%
# Minibatch loss at step 140000: 0.636779
# Minibatch accuracy: 92.19%
# Validation accuracy: 92.86%
# Validation accuracy character level: 97.13%
# Minibatch loss at step 142500: 0.462059
# Minibatch accuracy: 96.48%
# Validation accuracy: 93.02%
# Validation accuracy character level: 97.12%
# Minibatch loss at step 145000: 0.451615
# Minibatch accuracy: 95.70%
# Validation accuracy: 92.87%
# Validation accuracy character level: 97.13%
# Minibatch loss at step 147500: 0.442432
# Minibatch accuracy: 94.92%
# Validation accuracy: 92.95%
# Validation accuracy character level: 97.13%
# Minibatch loss at step 150000: 0.577226
# Minibatch accuracy: 93.75%
# Validation accuracy: 93.03%
# Validation accuracy character level: 97.19%
# Minibatch loss at step 152500: 0.614083
# Minibatch accuracy: 95.31%
# Validation accuracy: 93.21%
# Validation accuracy character level: 97.11%
# Minibatch loss at step 155000: 0.612363
# Minibatch accuracy: 93.75%
# Validation accuracy: 92.93%
# Validation accuracy character level: 97.10%
# Minibatch loss at step 157500: 0.367938
# Minibatch accuracy: 96.09%
# Validation accuracy: 92.98%
# Validation accuracy character level: 97.14%
# Minibatch loss at step 160000: 0.500329
# Minibatch accuracy: 95.70%
# Validation accuracy: 93.26%
# Validation accuracy character level: 97.18%
# Minibatch loss at step 162500: 0.689468
# Minibatch accuracy: 92.58%
# Validation accuracy: 93.07%
# Validation accuracy character level: 97.13%
# Minibatch loss at step 165000: 0.446313
# Minibatch accuracy: 95.70%
# Validation accuracy: 93.12%
# Validation accuracy character level: 97.14%
# Minibatch loss at step 167500: 0.349149
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.19%
# Validation accuracy character level: 97.14%
# Minibatch loss at step 170000: 0.599539
# Minibatch accuracy: 93.36%
# Validation accuracy: 92.98%
# Validation accuracy character level: 97.12%
# Minibatch loss at step 172500: 0.693823
# Minibatch accuracy: 93.75%
# Validation accuracy: 93.19%
# Validation accuracy character level: 97.14%
# Minibatch loss at step 175000: 0.401956
# Minibatch accuracy: 95.70%
# Validation accuracy: 93.02%
# Validation accuracy character level: 97.14%
# Minibatch loss at step 177500: 0.436597
# Minibatch accuracy: 96.09%
# Validation accuracy: 93.56%
# Validation accuracy character level: 97.22%
# Minibatch loss at step 180000: 0.409004
# Minibatch accuracy: 95.70%
# Validation accuracy: 93.07%
# Validation accuracy character level: 97.16%
# Minibatch loss at step 182500: 0.449392
# Minibatch accuracy: 95.70%
# Validation accuracy: 93.21%
# Validation accuracy character level: 97.17%
# Minibatch loss at step 185000: 0.474120
# Minibatch accuracy: 94.92%
# Validation accuracy: 93.19%
# Validation accuracy character level: 97.19%
# Minibatch loss at step 187500: 0.591619
# Minibatch accuracy: 94.14%
# Validation accuracy: 93.12%
# Validation accuracy character level: 97.08%
# Minibatch loss at step 190000: 0.576821
# Minibatch accuracy: 95.70%
# Validation accuracy: 93.02%
# Validation accuracy character level: 97.14%
# Minibatch loss at step 192500: 0.523855
# Minibatch accuracy: 94.53%
# Validation accuracy: 93.19%
# Validation accuracy character level: 97.15%
# Minibatch loss at step 195000: 0.222575
# Minibatch accuracy: 97.27%
# Validation accuracy: 93.14%
# Validation accuracy character level: 97.19%
# Minibatch loss at step 197500: 0.448690
# Minibatch accuracy: 96.09%
# Validation accuracy: 93.24%
# Validation accuracy character level: 97.17%
# Minibatch loss at step 200000: 0.529777
# Minibatch accuracy: 93.75%
# Validation accuracy: 93.26%
# Validation accuracy character level: 97.21%
# Minibatch loss at step 202500: 0.471879
# Minibatch accuracy: 93.36%
# Validation accuracy: 93.14%
# Validation accuracy character level: 97.16%
# Minibatch loss at step 205000: 0.339225
# Minibatch accuracy: 96.48%
# Validation accuracy: 93.24%
# Validation accuracy character level: 97.24%
# Minibatch loss at step 207500: 0.514319
# Minibatch accuracy: 95.70%
# Validation accuracy: 93.46%
# Validation accuracy character level: 97.28%
# Minibatch loss at step 210000: 0.358664
# Minibatch accuracy: 96.09%
# Validation accuracy: 93.38%
# Validation accuracy character level: 97.24%
# Minibatch loss at step 212500: 0.488667
# Minibatch accuracy: 95.31%
# Validation accuracy: 93.44%
# Validation accuracy character level: 97.23%
# Minibatch loss at step 215000: 0.405485
# Minibatch accuracy: 95.70%
# Validation accuracy: 93.44%
# Validation accuracy character level: 97.29%
# Minibatch loss at step 217500: 0.462141
# Minibatch accuracy: 96.48%
# Validation accuracy: 93.42%
# Validation accuracy character level: 97.21%
# Minibatch loss at step 220000: 0.417483
# Minibatch accuracy: 96.48%
# Validation accuracy: 93.28%
# Validation accuracy character level: 97.24%
# Minibatch loss at step 222500: 0.444570
# Minibatch accuracy: 95.70%
# Validation accuracy: 93.38%
# Validation accuracy character level: 97.22%
# Minibatch loss at step 225000: 0.335564
# Minibatch accuracy: 97.66%
# Validation accuracy: 93.35%
# Validation accuracy character level: 97.26%
# Minibatch loss at step 227500: 0.230491
# Minibatch accuracy: 98.05%
# Validation accuracy: 93.35%
# Validation accuracy character level: 97.19%
# Minibatch loss at step 230000: 0.262700
# Minibatch accuracy: 97.66%
# Validation accuracy: 93.35%
# Validation accuracy character level: 97.23%
# Minibatch loss at step 232500: 0.413187
# Minibatch accuracy: 96.09%
# Validation accuracy: 93.24%
# Validation accuracy character level: 97.19%
# Minibatch loss at step 235000: 0.332801
# Minibatch accuracy: 97.27%
# Validation accuracy: 93.49%
# Validation accuracy character level: 97.26%
# Minibatch loss at step 237500: 0.351016
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.33%
# Validation accuracy character level: 97.20%
# Minibatch loss at step 240000: 0.481122
# Minibatch accuracy: 94.92%
# Validation accuracy: 93.26%
# Validation accuracy character level: 97.22%
# Minibatch loss at step 242500: 0.328725
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.33%
# Validation accuracy character level: 97.17%
# Minibatch loss at step 245000: 0.410853
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.44%
# Validation accuracy character level: 97.23%
# Minibatch loss at step 247500: 0.455285
# Minibatch accuracy: 94.92%
# Validation accuracy: 93.47%
# Validation accuracy character level: 97.23%
# Minibatch loss at step 250000: 0.239496
# Minibatch accuracy: 97.27%
# Validation accuracy: 93.46%
# Validation accuracy character level: 97.26%
# Minibatch loss at step 252500: 0.319502
# Minibatch accuracy: 96.48%
# Validation accuracy: 93.58%
# Validation accuracy character level: 97.27%
# Minibatch loss at step 255000: 0.247562
# Minibatch accuracy: 97.66%
# Validation accuracy: 93.65%
# Validation accuracy character level: 97.30%
# Minibatch loss at step 257500: 0.319634
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.23%
# Validation accuracy character level: 97.19%
# Minibatch loss at step 260000: 0.493301
# Minibatch accuracy: 94.53%
# Validation accuracy: 93.61%
# Validation accuracy character level: 97.34%
# Minibatch loss at step 262500: 0.322990
# Minibatch accuracy: 96.48%
# Validation accuracy: 93.49%
# Validation accuracy character level: 97.23%
# Minibatch loss at step 265000: 0.260397
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.65%
# Validation accuracy character level: 97.29%
# Minibatch loss at step 267500: 0.314399
# Minibatch accuracy: 96.48%
# Validation accuracy: 93.70%
# Validation accuracy character level: 97.32%
# Minibatch loss at step 270000: 0.426228
# Minibatch accuracy: 96.09%
# Validation accuracy: 93.61%
# Validation accuracy character level: 97.29%
# Minibatch loss at step 272500: 0.381310
# Minibatch accuracy: 94.53%
# Validation accuracy: 93.67%
# Validation accuracy character level: 97.24%
# Minibatch loss at step 275000: 0.432982
# Minibatch accuracy: 97.27%
# Validation accuracy: 93.42%
# Validation accuracy character level: 97.27%
# Minibatch loss at step 277500: 0.374559
# Minibatch accuracy: 97.66%
# Validation accuracy: 93.54%
# Validation accuracy character level: 97.25%
# Minibatch loss at step 280000: 0.376208
# Minibatch accuracy: 98.05%
# Validation accuracy: 93.58%
# Validation accuracy character level: 97.29%
# Minibatch loss at step 282500: 0.255768
# Minibatch accuracy: 98.05%
# Validation accuracy: 93.65%
# Validation accuracy character level: 97.30%
# Minibatch loss at step 285000: 0.282133
# Minibatch accuracy: 98.44%
# Validation accuracy: 93.51%
# Validation accuracy character level: 97.28%
# Minibatch loss at step 287500: 0.375109
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.60%
# Validation accuracy character level: 97.29%
# Minibatch loss at step 290000: 0.327651
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.53%
# Validation accuracy character level: 97.32%
# Minibatch loss at step 292500: 0.293901
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.56%
# Validation accuracy character level: 97.27%
# Minibatch loss at step 295000: 0.387384
# Minibatch accuracy: 94.53%
# Validation accuracy: 93.54%
# Validation accuracy character level: 97.29%
# Minibatch loss at step 297500: 0.336554
# Minibatch accuracy: 96.48%
# Validation accuracy: 93.61%
# Validation accuracy character level: 97.29%
# Minibatch loss at step 300000: 0.548400
# Minibatch accuracy: 94.92%
# Validation accuracy: 93.46%
# Validation accuracy character level: 97.27%
# Minibatch loss at step 302500: 0.334855
# Minibatch accuracy: 98.05%
# Validation accuracy: 93.68%
# Validation accuracy character level: 97.29%
# Minibatch loss at step 305000: 0.514544
# Minibatch accuracy: 95.31%
# Validation accuracy: 93.58%
# Validation accuracy character level: 97.26%
# Minibatch loss at step 307500: 0.436721
# Minibatch accuracy: 96.48%
# Validation accuracy: 93.63%
# Validation accuracy character level: 97.26%
# Minibatch loss at step 310000: 0.583510
# Minibatch accuracy: 96.48%
# Validation accuracy: 93.58%
# Validation accuracy character level: 97.30%
# Minibatch loss at step 312500: 0.270995
# Minibatch accuracy: 96.48%
# Validation accuracy: 93.65%
# Validation accuracy character level: 97.27%
# Minibatch loss at step 315000: 0.311164
# Minibatch accuracy: 95.70%
# Validation accuracy: 93.44%
# Validation accuracy character level: 97.27%
# Minibatch loss at step 317500: 0.260388
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.72%
# Validation accuracy character level: 97.29%
# Minibatch loss at step 320000: 0.287329
# Minibatch accuracy: 97.27%
# Validation accuracy: 93.49%
# Validation accuracy character level: 97.27%
# Minibatch loss at step 322500: 0.322828
# Minibatch accuracy: 96.48%
# Validation accuracy: 93.61%
# Validation accuracy character level: 97.27%
# Minibatch loss at step 325000: 0.259542
# Minibatch accuracy: 97.66%
# Validation accuracy: 93.70%
# Validation accuracy character level: 97.29%
# Minibatch loss at step 327500: 0.238598
# Minibatch accuracy: 98.83%
# Validation accuracy: 93.58%
# Validation accuracy character level: 97.25%
# Minibatch loss at step 330000: 0.364666
# Minibatch accuracy: 96.48%
# Validation accuracy: 93.46%
# Validation accuracy character level: 97.30%
# Minibatch loss at step 332500: 0.315505
# Minibatch accuracy: 96.48%
# Validation accuracy: 93.56%
# Validation accuracy character level: 97.25%
# Minibatch loss at step 335000: 0.419619
# Minibatch accuracy: 95.70%
# Validation accuracy: 93.81%
# Validation accuracy character level: 97.34%
# Minibatch loss at step 337500: 0.410823
# Minibatch accuracy: 95.31%
# Validation accuracy: 93.58%
# Validation accuracy character level: 97.28%
# Minibatch loss at step 340000: 0.558673
# Minibatch accuracy: 94.53%
# Validation accuracy: 93.47%
# Validation accuracy character level: 97.29%
# Minibatch loss at step 342500: 0.356085
# Minibatch accuracy: 96.48%
# Validation accuracy: 93.70%
# Validation accuracy character level: 97.29%
# Minibatch loss at step 345000: 0.265952
# Minibatch accuracy: 96.48%
# Validation accuracy: 93.70%
# Validation accuracy character level: 97.34%
# Minibatch loss at step 347500: 0.295798
# Minibatch accuracy: 97.27%
# Validation accuracy: 93.68%
# Validation accuracy character level: 97.30%
# Minibatch loss at step 350000: 0.445067
# Minibatch accuracy: 95.70%
# Validation accuracy: 93.65%
# Validation accuracy character level: 97.31%
# Minibatch loss at step 352500: 0.421415
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.67%
# Validation accuracy character level: 97.27%
# Minibatch loss at step 355000: 0.251931
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.79%
# Validation accuracy character level: 97.35%
# Minibatch loss at step 357500: 0.634816
# Minibatch accuracy: 94.53%
# Validation accuracy: 93.70%
# Validation accuracy character level: 97.27%
# Minibatch loss at step 360000: 0.432243
# Minibatch accuracy: 96.09%
# Validation accuracy: 93.68%
# Validation accuracy character level: 97.32%
# Minibatch loss at step 362500: 0.206249
# Minibatch accuracy: 98.44%
# Validation accuracy: 93.58%
# Validation accuracy character level: 97.24%
# Minibatch loss at step 365000: 0.356047
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.53%
# Validation accuracy character level: 97.30%
# Minibatch loss at step 367500: 0.342049
# Minibatch accuracy: 98.05%
# Validation accuracy: 93.72%
# Validation accuracy character level: 97.29%
# Minibatch loss at step 370000: 0.281480
# Minibatch accuracy: 98.05%
# Validation accuracy: 93.58%
# Validation accuracy character level: 97.31%
# Minibatch loss at step 372500: 0.395402
# Minibatch accuracy: 96.09%
# Validation accuracy: 93.58%
# Validation accuracy character level: 97.27%
# Minibatch loss at step 375000: 0.384202
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.72%
# Validation accuracy character level: 97.36%
# Minibatch loss at step 377500: 0.266697
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.54%
# Validation accuracy character level: 97.25%
# Minibatch loss at step 380000: 0.367475
# Minibatch accuracy: 95.31%
# Validation accuracy: 93.61%
# Validation accuracy character level: 97.33%
# Minibatch loss at step 382500: 0.418440
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.63%
# Validation accuracy character level: 97.31%
# Minibatch loss at step 385000: 0.613459
# Minibatch accuracy: 95.31%
# Validation accuracy: 93.61%
# Validation accuracy character level: 97.29%
# Minibatch loss at step 387500: 0.352507
# Minibatch accuracy: 97.66%
# Validation accuracy: 93.82%
# Validation accuracy character level: 97.34%
# Minibatch loss at step 390000: 0.378295
# Minibatch accuracy: 97.27%
# Validation accuracy: 93.79%
# Validation accuracy character level: 97.36%
# Minibatch loss at step 392500: 0.227646
# Minibatch accuracy: 97.66%
# Validation accuracy: 93.58%
# Validation accuracy character level: 97.28%
# Minibatch loss at step 395000: 0.482698
# Minibatch accuracy: 94.92%
# Validation accuracy: 93.77%
# Validation accuracy character level: 97.38%
# Minibatch loss at step 397500: 0.588392
# Minibatch accuracy: 95.31%
# Validation accuracy: 93.81%
# Validation accuracy character level: 97.32%
# Minibatch loss at step 400000: 0.375791
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.67%
# Validation accuracy character level: 97.33%
# Minibatch loss at step 402500: 0.434478
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.60%
# Validation accuracy character level: 97.28%
# Minibatch loss at step 405000: 0.206993
# Minibatch accuracy: 97.27%
# Validation accuracy: 93.58%
# Validation accuracy character level: 97.27%
# Minibatch loss at step 407500: 0.439393
# Minibatch accuracy: 94.92%
# Validation accuracy: 93.58%
# Validation accuracy character level: 97.29%
# Minibatch loss at step 410000: 0.213749
# Minibatch accuracy: 97.27%
# Validation accuracy: 93.90%
# Validation accuracy character level: 97.36%
# Minibatch loss at step 412500: 0.270188
# Minibatch accuracy: 95.70%
# Validation accuracy: 93.68%
# Validation accuracy character level: 97.28%
# Minibatch loss at step 415000: 0.420567
# Minibatch accuracy: 97.27%
# Validation accuracy: 93.60%
# Validation accuracy character level: 97.29%
# Minibatch loss at step 417500: 0.393142
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.67%
# Validation accuracy character level: 97.31%
# Minibatch loss at step 420000: 0.225905
# Minibatch accuracy: 97.27%
# Validation accuracy: 93.54%
# Validation accuracy character level: 97.28%
# Minibatch loss at step 422500: 0.495802
# Minibatch accuracy: 95.31%
# Validation accuracy: 93.74%
# Validation accuracy character level: 97.29%
# Minibatch loss at step 425000: 0.528887
# Minibatch accuracy: 95.70%
# Validation accuracy: 93.79%
# Validation accuracy character level: 97.38%
# Minibatch loss at step 427500: 0.360766
# Minibatch accuracy: 96.09%
# Validation accuracy: 93.47%
# Validation accuracy character level: 97.24%
# Minibatch loss at step 430000: 0.273646
# Minibatch accuracy: 98.05%
# Validation accuracy: 93.79%
# Validation accuracy character level: 97.34%
# Minibatch loss at step 432500: 0.363832
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.82%
# Validation accuracy character level: 97.31%
# Minibatch loss at step 435000: 0.249214
# Minibatch accuracy: 98.05%
# Validation accuracy: 93.72%
# Validation accuracy character level: 97.31%
# Minibatch loss at step 437500: 0.436356
# Minibatch accuracy: 95.31%
# Validation accuracy: 93.65%
# Validation accuracy character level: 97.28%
# Minibatch loss at step 440000: 0.206823
# Minibatch accuracy: 98.05%
# Validation accuracy: 93.67%
# Validation accuracy character level: 97.26%
# Minibatch loss at step 442500: 0.242394
# Minibatch accuracy: 98.05%
# Validation accuracy: 93.86%
# Validation accuracy character level: 97.34%
# Minibatch loss at step 445000: 0.410289
# Minibatch accuracy: 95.31%
# Validation accuracy: 93.61%
# Validation accuracy character level: 97.29%
# Minibatch loss at step 447500: 0.218324
# Minibatch accuracy: 98.44%
# Validation accuracy: 93.61%
# Validation accuracy character level: 97.29%
# Minibatch loss at step 450000: 0.308451
# Minibatch accuracy: 96.48%
# Validation accuracy: 93.86%
# Validation accuracy character level: 97.37%
# Minibatch loss at step 452500: 0.361165
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.65%
# Validation accuracy character level: 97.27%
# Minibatch loss at step 455000: 0.427217
# Minibatch accuracy: 97.27%
# Validation accuracy: 93.75%
# Validation accuracy character level: 97.30%
# Minibatch loss at step 457500: 0.351102
# Minibatch accuracy: 98.44%
# Validation accuracy: 93.67%
# Validation accuracy character level: 97.26%
# Minibatch loss at step 460000: 0.292565
# Minibatch accuracy: 97.66%
# Validation accuracy: 93.75%
# Validation accuracy character level: 97.31%
# Minibatch loss at step 462500: 0.313706
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.79%
# Validation accuracy character level: 97.30%
# Minibatch loss at step 465000: 0.283408
# Minibatch accuracy: 97.66%
# Validation accuracy: 93.91%
# Validation accuracy character level: 97.36%
# Minibatch loss at step 467500: 0.174738
# Minibatch accuracy: 97.27%
# Validation accuracy: 93.91%
# Validation accuracy character level: 97.36%
# Minibatch loss at step 470000: 0.325882
# Minibatch accuracy: 98.83%
# Validation accuracy: 93.88%
# Validation accuracy character level: 97.35%
# Minibatch loss at step 472500: 0.220593
# Minibatch accuracy: 98.44%
# Validation accuracy: 93.88%
# Validation accuracy character level: 97.34%
# Minibatch loss at step 475000: 0.326428
# Minibatch accuracy: 98.05%
# Validation accuracy: 94.11%
# Validation accuracy character level: 97.39%
# Minibatch loss at step 477500: 0.295603
# Minibatch accuracy: 97.27%
# Validation accuracy: 93.93%
# Validation accuracy character level: 97.33%
# Minibatch loss at step 480000: 0.301411
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.84%
# Validation accuracy character level: 97.33%
# Minibatch loss at step 482500: 0.290994
# Minibatch accuracy: 98.05%
# Validation accuracy: 93.81%
# Validation accuracy character level: 97.30%
# Minibatch loss at step 485000: 0.334289
# Minibatch accuracy: 97.27%
# Validation accuracy: 93.84%
# Validation accuracy character level: 97.37%
# Minibatch loss at step 487500: 0.333945
# Minibatch accuracy: 98.83%
# Validation accuracy: 93.91%
# Validation accuracy character level: 97.33%
# Minibatch loss at step 490000: 0.390838
# Minibatch accuracy: 95.70%
# Validation accuracy: 93.70%
# Validation accuracy character level: 97.30%
# Minibatch loss at step 492500: 0.210215
# Minibatch accuracy: 98.44%
# Validation accuracy: 93.90%
# Validation accuracy character level: 97.33%
# Minibatch loss at step 495000: 0.424879
# Minibatch accuracy: 94.92%
# Validation accuracy: 93.72%
# Validation accuracy character level: 97.29%
# Minibatch loss at step 497500: 0.438833
# Minibatch accuracy: 95.70%
# Validation accuracy: 93.93%
# Validation accuracy character level: 97.36%
# Minibatch loss at step 500000: 0.509345
# Minibatch accuracy: 96.09%
# Validation accuracy: 94.00%
# Validation accuracy character level: 97.41%
# Minibatch loss at step 502500: 0.305092
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.70%
# Validation accuracy character level: 97.28%
# Minibatch loss at step 505000: 0.369052
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.77%
# Validation accuracy character level: 97.29%
# Minibatch loss at step 507500: 0.246516
# Minibatch accuracy: 98.44%
# Validation accuracy: 93.91%
# Validation accuracy character level: 97.32%
# Minibatch loss at step 510000: 0.336791
# Minibatch accuracy: 97.66%
# Validation accuracy: 93.95%
# Validation accuracy character level: 97.39%
# Minibatch loss at step 512500: 0.244226
# Minibatch accuracy: 97.27%
# Validation accuracy: 93.79%
# Validation accuracy character level: 97.29%
# Minibatch loss at step 515000: 0.468593
# Minibatch accuracy: 95.70%
# Validation accuracy: 93.86%
# Validation accuracy character level: 97.37%
# Minibatch loss at step 517500: 0.375591
# Minibatch accuracy: 96.48%
# Validation accuracy: 93.93%
# Validation accuracy character level: 97.33%
# Minibatch loss at step 520000: 0.220011
# Minibatch accuracy: 97.66%
# Validation accuracy: 93.68%
# Validation accuracy character level: 97.34%
# Minibatch loss at step 522500: 0.235151
# Minibatch accuracy: 98.05%
# Validation accuracy: 93.86%
# Validation accuracy character level: 97.32%
# Minibatch loss at step 525000: 0.494980
# Minibatch accuracy: 95.70%
# Validation accuracy: 93.81%
# Validation accuracy character level: 97.32%
# Minibatch loss at step 527500: 0.302737
# Minibatch accuracy: 95.70%
# Validation accuracy: 93.77%
# Validation accuracy character level: 97.31%
# Minibatch loss at step 530000: 0.215486
# Minibatch accuracy: 97.27%
# Validation accuracy: 93.97%
# Validation accuracy character level: 97.38%
# Minibatch loss at step 532500: 0.311067
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.81%
# Validation accuracy character level: 97.34%
# Minibatch loss at step 535000: 0.186834
# Minibatch accuracy: 97.27%
# Validation accuracy: 93.91%
# Validation accuracy character level: 97.42%
# Minibatch loss at step 537500: 0.382531
# Minibatch accuracy: 96.48%
# Validation accuracy: 93.79%
# Validation accuracy character level: 97.33%
# Minibatch loss at step 540000: 0.324929
# Minibatch accuracy: 96.48%
# Validation accuracy: 93.81%
# Validation accuracy character level: 97.36%
# Minibatch loss at step 542500: 0.310405
# Minibatch accuracy: 97.27%
# Validation accuracy: 93.79%
# Validation accuracy character level: 97.28%
# Minibatch loss at step 545000: 0.286246
# Minibatch accuracy: 97.66%
# Validation accuracy: 93.93%
# Validation accuracy character level: 97.34%
# Minibatch loss at step 547500: 0.215754
# Minibatch accuracy: 98.05%
# Validation accuracy: 93.81%
# Validation accuracy character level: 97.30%
# Minibatch loss at step 550000: 0.313974
# Minibatch accuracy: 97.27%
# Validation accuracy: 93.88%
# Validation accuracy character level: 97.35%
# Minibatch loss at step 552500: 0.376761
# Minibatch accuracy: 96.09%
# Validation accuracy: 93.68%
# Validation accuracy character level: 97.30%
# Minibatch loss at step 555000: 0.280265
# Minibatch accuracy: 98.05%
# Validation accuracy: 93.81%
# Validation accuracy character level: 97.32%
# Minibatch loss at step 557500: 0.329273
# Minibatch accuracy: 98.05%
# Validation accuracy: 93.75%
# Validation accuracy character level: 97.26%
# Minibatch loss at step 560000: 0.296248
# Minibatch accuracy: 97.27%
# Validation accuracy: 93.90%
# Validation accuracy character level: 97.34%
# Minibatch loss at step 562500: 0.410104
# Minibatch accuracy: 94.14%
# Validation accuracy: 93.77%
# Validation accuracy character level: 97.29%
# Minibatch loss at step 565000: 0.228565
# Minibatch accuracy: 97.66%
# Validation accuracy: 93.86%
# Validation accuracy character level: 97.34%
# Minibatch loss at step 567500: 0.444695
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.86%
# Validation accuracy character level: 97.30%
# Minibatch loss at step 570000: 0.239246
# Minibatch accuracy: 97.66%
# Validation accuracy: 93.81%
# Validation accuracy character level: 97.34%
# Minibatch loss at step 572500: 0.323916
# Minibatch accuracy: 97.66%
# Validation accuracy: 93.93%
# Validation accuracy character level: 97.31%
# Minibatch loss at step 575000: 0.337412
# Minibatch accuracy: 97.27%
# Validation accuracy: 94.02%
# Validation accuracy character level: 97.39%
# Minibatch loss at step 577500: 0.346185
# Minibatch accuracy: 98.05%
# Validation accuracy: 93.82%
# Validation accuracy character level: 97.28%
# Minibatch loss at step 580000: 0.317361
# Minibatch accuracy: 96.48%
# Validation accuracy: 93.77%
# Validation accuracy character level: 97.33%
# Minibatch loss at step 582500: 0.378534
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.72%
# Validation accuracy character level: 97.27%
# Minibatch loss at step 585000: 0.263686
# Minibatch accuracy: 98.05%
# Validation accuracy: 93.77%
# Validation accuracy character level: 97.35%
# Minibatch loss at step 587500: 0.240080
# Minibatch accuracy: 98.83%
# Validation accuracy: 93.97%
# Validation accuracy character level: 97.29%
# Minibatch loss at step 590000: 0.278828
# Minibatch accuracy: 97.27%
# Validation accuracy: 93.65%
# Validation accuracy character level: 97.30%
# Minibatch loss at step 592500: 0.238480
# Minibatch accuracy: 97.66%
# Validation accuracy: 93.90%
# Validation accuracy character level: 97.31%
# Minibatch loss at step 595000: 0.343773
# Minibatch accuracy: 97.66%
# Validation accuracy: 93.77%
# Validation accuracy character level: 97.29%
# Minibatch loss at step 597500: 0.341020
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.70%
# Validation accuracy character level: 97.26%
# Minibatch loss at step 600000: 0.294422
# Minibatch accuracy: 98.44%
# Validation accuracy: 93.98%
# Validation accuracy character level: 97.39%
# Minibatch loss at step 602500: 0.268649
# Minibatch accuracy: 98.44%
# Validation accuracy: 93.84%
# Validation accuracy character level: 97.28%
# Minibatch loss at step 605000: 0.399419
# Minibatch accuracy: 97.27%
# Validation accuracy: 93.68%
# Validation accuracy character level: 97.28%
# Minibatch loss at step 607500: 0.309295
# Minibatch accuracy: 97.27%
# Validation accuracy: 93.95%
# Validation accuracy character level: 97.31%
# Minibatch loss at step 610000: 0.353124
# Minibatch accuracy: 97.27%
# Validation accuracy: 93.63%
# Validation accuracy character level: 97.32%
# Minibatch loss at step 612500: 0.309765
# Minibatch accuracy: 98.05%
# Validation accuracy: 93.82%
# Validation accuracy character level: 97.31%
# Minibatch loss at step 615000: 0.308685
# Minibatch accuracy: 96.09%
# Validation accuracy: 94.00%
# Validation accuracy character level: 97.36%
# Minibatch loss at step 617500: 0.296582
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.88%
# Validation accuracy character level: 97.35%
# Minibatch loss at step 620000: 0.292830
# Minibatch accuracy: 98.05%
# Validation accuracy: 93.93%
# Validation accuracy character level: 97.39%
# Minibatch loss at step 622500: 0.258901
# Minibatch accuracy: 97.27%
# Validation accuracy: 93.84%
# Validation accuracy character level: 97.30%
# Minibatch loss at step 625000: 0.273712
# Minibatch accuracy: 96.88%
# Validation accuracy: 94.02%
# Validation accuracy character level: 97.36%
# Minibatch loss at step 627500: 0.331735
# Minibatch accuracy: 97.27%
# Validation accuracy: 93.86%
# Validation accuracy character level: 97.32%
# Minibatch loss at step 630000: 0.163279
# Minibatch accuracy: 99.22%
# Validation accuracy: 94.00%
# Validation accuracy character level: 97.39%
# Minibatch loss at step 632500: 0.350273
# Minibatch accuracy: 97.66%
# Validation accuracy: 93.91%
# Validation accuracy character level: 97.31%
# Minibatch loss at step 635000: 0.303661
# Minibatch accuracy: 96.09%
# Validation accuracy: 93.88%
# Validation accuracy character level: 97.35%
# Minibatch loss at step 637500: 0.282822
# Minibatch accuracy: 96.48%
# Validation accuracy: 93.86%
# Validation accuracy character level: 97.30%
# Minibatch loss at step 640000: 0.459789
# Minibatch accuracy: 97.66%
# Validation accuracy: 93.93%
# Validation accuracy character level: 97.34%
# Minibatch loss at step 642500: 0.321037
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.95%
# Validation accuracy character level: 97.28%
# Minibatch loss at step 645000: 0.315238
# Minibatch accuracy: 97.27%
# Validation accuracy: 93.97%
# Validation accuracy character level: 97.34%
# Minibatch loss at step 647500: 0.204231
# Minibatch accuracy: 99.22%
# Validation accuracy: 94.05%
# Validation accuracy character level: 97.35%
# Minibatch loss at step 650000: 0.412437
# Minibatch accuracy: 94.53%
# Validation accuracy: 93.88%
# Validation accuracy character level: 97.35%
# Minibatch loss at step 652500: 0.494072
# Minibatch accuracy: 96.48%
# Validation accuracy: 93.91%
# Validation accuracy character level: 97.34%
# Minibatch loss at step 655000: 0.309238
# Minibatch accuracy: 96.48%
# Validation accuracy: 93.93%
# Validation accuracy character level: 97.37%
# Minibatch loss at step 657500: 0.434081
# Minibatch accuracy: 98.05%
# Validation accuracy: 93.82%
# Validation accuracy character level: 97.32%
# Minibatch loss at step 660000: 0.378988
# Minibatch accuracy: 98.05%
# Validation accuracy: 93.75%
# Validation accuracy character level: 97.33%
# Minibatch loss at step 662500: 0.285177
# Minibatch accuracy: 96.48%
# Validation accuracy: 93.70%
# Validation accuracy character level: 97.29%
# Minibatch loss at step 665000: 0.286687
# Minibatch accuracy: 98.83%
# Validation accuracy: 93.79%
# Validation accuracy character level: 97.31%
# Minibatch loss at step 667500: 0.293409
# Minibatch accuracy: 98.05%
# Validation accuracy: 93.91%
# Validation accuracy character level: 97.30%
# Minibatch loss at step 670000: 0.325524
# Minibatch accuracy: 98.44%
# Validation accuracy: 94.05%
# Validation accuracy character level: 97.39%
# Minibatch loss at step 672500: 0.454573
# Minibatch accuracy: 97.66%
# Validation accuracy: 93.88%
# Validation accuracy character level: 97.29%
# Minibatch loss at step 675000: 0.313689
# Minibatch accuracy: 97.66%
# Validation accuracy: 93.84%
# Validation accuracy character level: 97.33%
# Minibatch loss at step 677500: 0.191275
# Minibatch accuracy: 98.83%
# Validation accuracy: 93.90%
# Validation accuracy character level: 97.33%
# Minibatch loss at step 680000: 0.215335
# Minibatch accuracy: 98.44%
# Validation accuracy: 94.04%
# Validation accuracy character level: 97.36%
# Minibatch loss at step 682500: 0.283570
# Minibatch accuracy: 97.27%
# Validation accuracy: 94.07%
# Validation accuracy character level: 97.38%
# Minibatch loss at step 685000: 0.314400
# Minibatch accuracy: 96.48%
# Validation accuracy: 93.93%
# Validation accuracy character level: 97.39%
# Minibatch loss at step 687500: 0.332048
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.97%
# Validation accuracy character level: 97.35%
# Minibatch loss at step 690000: 0.168374
# Minibatch accuracy: 98.05%
# Validation accuracy: 93.90%
# Validation accuracy character level: 97.36%
# Minibatch loss at step 692500: 0.182271
# Minibatch accuracy: 98.83%
# Validation accuracy: 94.04%
# Validation accuracy character level: 97.34%
# Minibatch loss at step 695000: 0.234310
# Minibatch accuracy: 97.66%
# Validation accuracy: 93.91%
# Validation accuracy character level: 97.37%
# Minibatch loss at step 697500: 0.195687
# Minibatch accuracy: 98.05%
# Validation accuracy: 94.00%
# Validation accuracy character level: 97.32%
# Minibatch loss at step 700000: 0.140456
# Minibatch accuracy: 98.05%
# Validation accuracy: 93.84%
# Validation accuracy character level: 97.33%
# Minibatch loss at step 702500: 0.268554
# Minibatch accuracy: 97.66%
# Validation accuracy: 94.02%
# Validation accuracy character level: 97.35%
# Minibatch loss at step 705000: 0.237189
# Minibatch accuracy: 97.66%
# Validation accuracy: 94.05%
# Validation accuracy character level: 97.38%
# Minibatch loss at step 707500: 0.211985
# Minibatch accuracy: 99.22%
# Validation accuracy: 94.09%
# Validation accuracy character level: 97.37%
# Minibatch loss at step 710000: 0.427809
# Minibatch accuracy: 98.05%
# Validation accuracy: 94.02%
# Validation accuracy character level: 97.35%
# Minibatch loss at step 712500: 0.433394
# Minibatch accuracy: 96.48%
# Validation accuracy: 93.97%
# Validation accuracy character level: 97.30%
# Minibatch loss at step 715000: 0.205959
# Minibatch accuracy: 98.44%
# Validation accuracy: 94.05%
# Validation accuracy character level: 97.37%
# Minibatch loss at step 717500: 0.341390
# Minibatch accuracy: 96.88%
# Validation accuracy: 94.04%
# Validation accuracy character level: 97.33%
# Minibatch loss at step 720000: 0.415476
# Minibatch accuracy: 96.88%
# Validation accuracy: 94.02%
# Validation accuracy character level: 97.37%
# Minibatch loss at step 722500: 0.283945
# Minibatch accuracy: 97.27%
# Validation accuracy: 94.02%
# Validation accuracy character level: 97.34%
# Minibatch loss at step 725000: 0.350465
# Minibatch accuracy: 96.88%
# Validation accuracy: 94.11%
# Validation accuracy character level: 97.40%
# Minibatch loss at step 727500: 0.352335
# Minibatch accuracy: 97.66%
# Validation accuracy: 93.91%
# Validation accuracy character level: 97.29%
# Minibatch loss at step 730000: 0.349318
# Minibatch accuracy: 97.66%
# Validation accuracy: 93.98%
# Validation accuracy character level: 97.36%
# Minibatch loss at step 732500: 0.339762
# Minibatch accuracy: 96.09%
# Validation accuracy: 94.04%
# Validation accuracy character level: 97.34%
# Minibatch loss at step 735000: 0.420650
# Minibatch accuracy: 96.48%
# Validation accuracy: 94.00%
# Validation accuracy character level: 97.35%
# Minibatch loss at step 737500: 0.228017
# Minibatch accuracy: 98.05%
# Validation accuracy: 94.00%
# Validation accuracy character level: 97.36%
# Minibatch loss at step 740000: 0.268571
# Minibatch accuracy: 97.66%
# Validation accuracy: 93.90%
# Validation accuracy character level: 97.34%
# Minibatch loss at step 742500: 0.393947
# Minibatch accuracy: 95.70%
# Validation accuracy: 93.88%
# Validation accuracy character level: 97.30%
# Minibatch loss at step 745000: 0.329141
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.88%
# Validation accuracy character level: 97.29%
# Minibatch loss at step 747500: 0.235702
# Minibatch accuracy: 97.66%
# Validation accuracy: 93.97%
# Validation accuracy character level: 97.28%
# Minibatch loss at step 750000: 0.287223
# Minibatch accuracy: 97.66%
# Validation accuracy: 94.02%
# Validation accuracy character level: 97.34%
# Minibatch loss at step 752500: 0.234597
# Minibatch accuracy: 98.05%
# Validation accuracy: 93.88%
# Validation accuracy character level: 97.28%
# Minibatch loss at step 755000: 0.241584
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.97%
# Validation accuracy character level: 97.37%
# Minibatch loss at step 757500: 0.240798
# Minibatch accuracy: 98.44%
# Validation accuracy: 94.09%
# Validation accuracy character level: 97.36%
# Minibatch loss at step 760000: 0.390347
# Minibatch accuracy: 95.70%
# Validation accuracy: 94.00%
# Validation accuracy character level: 97.36%
# Minibatch loss at step 762500: 0.355174
# Minibatch accuracy: 97.66%
# Validation accuracy: 94.05%
# Validation accuracy character level: 97.34%
# Minibatch loss at step 765000: 0.240040
# Minibatch accuracy: 97.66%
# Validation accuracy: 93.75%
# Validation accuracy character level: 97.32%
# Minibatch loss at step 767500: 0.261828
# Minibatch accuracy: 99.22%
# Validation accuracy: 94.05%
# Validation accuracy character level: 97.36%
# Minibatch loss at step 770000: 0.268147
# Minibatch accuracy: 98.05%
# Validation accuracy: 93.82%
# Validation accuracy character level: 97.31%
# Minibatch loss at step 772500: 0.208658
# Minibatch accuracy: 98.83%
# Validation accuracy: 94.05%
# Validation accuracy character level: 97.34%
# Minibatch loss at step 775000: 0.276128
# Minibatch accuracy: 96.48%
# Validation accuracy: 94.02%
# Validation accuracy character level: 97.38%
# Minibatch loss at step 777500: 0.369656
# Minibatch accuracy: 96.09%
# Validation accuracy: 94.07%
# Validation accuracy character level: 97.33%
# Minibatch loss at step 780000: 0.247798
# Minibatch accuracy: 98.44%
# Validation accuracy: 94.04%
# Validation accuracy character level: 97.39%
# Minibatch loss at step 782500: 0.337420
# Minibatch accuracy: 98.83%
# Validation accuracy: 93.97%
# Validation accuracy character level: 97.32%
# Minibatch loss at step 785000: 0.192511
# Minibatch accuracy: 98.44%
# Validation accuracy: 93.97%
# Validation accuracy character level: 97.38%
# Minibatch loss at step 787500: 0.197749
# Minibatch accuracy: 98.44%
# Validation accuracy: 94.12%
# Validation accuracy character level: 97.37%
# Minibatch loss at step 790000: 0.287514
# Minibatch accuracy: 98.44%
# Validation accuracy: 93.98%
# Validation accuracy character level: 97.34%
# Minibatch loss at step 792500: 0.428208
# Minibatch accuracy: 96.48%
# Validation accuracy: 94.12%
# Validation accuracy character level: 97.41%
# Minibatch loss at step 795000: 0.263400
# Minibatch accuracy: 98.44%
# Validation accuracy: 93.93%
# Validation accuracy character level: 97.35%
# Minibatch loss at step 797500: 0.266183
# Minibatch accuracy: 96.09%
# Validation accuracy: 94.02%
# Validation accuracy character level: 97.33%
# Minibatch loss at step 800000: 0.174132
# Minibatch accuracy: 98.05%
# Validation accuracy: 93.97%
# Validation accuracy character level: 97.38%
# Minibatch loss at step 802500: 0.301053
# Minibatch accuracy: 98.44%
# Validation accuracy: 94.07%
# Validation accuracy character level: 97.38%
# Minibatch loss at step 805000: 0.254705
# Minibatch accuracy: 97.27%
# Validation accuracy: 93.93%
# Validation accuracy character level: 97.33%
# Minibatch loss at step 807500: 0.353673
# Minibatch accuracy: 97.27%
# Validation accuracy: 94.14%
# Validation accuracy character level: 97.40%
# Minibatch loss at step 810000: 0.239564
# Minibatch accuracy: 97.27%
# Validation accuracy: 93.98%
# Validation accuracy character level: 97.35%
# Minibatch loss at step 812500: 0.307648
# Minibatch accuracy: 98.44%
# Validation accuracy: 94.00%
# Validation accuracy character level: 97.36%
# Minibatch loss at step 815000: 0.310076
# Minibatch accuracy: 97.66%
# Validation accuracy: 93.97%
# Validation accuracy character level: 97.38%
# Minibatch loss at step 817500: 0.295884
# Minibatch accuracy: 97.66%
# Validation accuracy: 93.93%
# Validation accuracy character level: 97.31%
# Minibatch loss at step 820000: 0.248414
# Minibatch accuracy: 98.83%
# Validation accuracy: 94.05%
# Validation accuracy character level: 97.39%
# Minibatch loss at step 822500: 0.200644
# Minibatch accuracy: 99.22%
# Validation accuracy: 94.11%
# Validation accuracy character level: 97.35%
# Minibatch loss at step 825000: 0.435424
# Minibatch accuracy: 98.44%
# Validation accuracy: 94.14%
# Validation accuracy character level: 97.38%
# Minibatch loss at step 827500: 0.282398
# Minibatch accuracy: 96.48%
# Validation accuracy: 93.91%
# Validation accuracy character level: 97.34%
# Minibatch loss at step 830000: 0.248747
# Minibatch accuracy: 96.48%
# Validation accuracy: 94.02%
# Validation accuracy character level: 97.39%
# Minibatch loss at step 832500: 0.253989
# Minibatch accuracy: 98.44%
# Validation accuracy: 94.05%
# Validation accuracy character level: 97.38%
# Minibatch loss at step 835000: 0.325029
# Minibatch accuracy: 96.88%
# Validation accuracy: 94.04%
# Validation accuracy character level: 97.35%
# Minibatch loss at step 837500: 0.230913
# Minibatch accuracy: 98.44%
# Validation accuracy: 94.04%
# Validation accuracy character level: 97.35%
# Minibatch loss at step 840000: 0.361840
# Minibatch accuracy: 97.27%
# Validation accuracy: 94.00%
# Validation accuracy character level: 97.41%
# Minibatch loss at step 842500: 0.346957
# Minibatch accuracy: 97.66%
# Validation accuracy: 94.00%
# Validation accuracy character level: 97.36%
# Minibatch loss at step 845000: 0.250490
# Minibatch accuracy: 98.44%
# Validation accuracy: 94.04%
# Validation accuracy character level: 97.37%
# Minibatch loss at step 847500: 0.162270
# Minibatch accuracy: 99.61%
# Validation accuracy: 93.82%
# Validation accuracy character level: 97.32%
# Minibatch loss at step 850000: 0.399667
# Minibatch accuracy: 97.66%
# Validation accuracy: 93.88%
# Validation accuracy character level: 97.36%
# Minibatch loss at step 852500: 0.324291
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.90%
# Validation accuracy character level: 97.34%
# Minibatch loss at step 855000: 0.238358
# Minibatch accuracy: 97.66%
# Validation accuracy: 94.04%
# Validation accuracy character level: 97.38%
# Minibatch loss at step 857500: 0.387785
# Minibatch accuracy: 96.88%
# Validation accuracy: 94.04%
# Validation accuracy character level: 97.42%
# Minibatch loss at step 860000: 0.190569
# Minibatch accuracy: 99.22%
# Validation accuracy: 94.04%
# Validation accuracy character level: 97.39%
# Minibatch loss at step 862500: 0.375758
# Minibatch accuracy: 95.31%
# Validation accuracy: 94.02%
# Validation accuracy character level: 97.37%
# Minibatch loss at step 865000: 0.239254
# Minibatch accuracy: 99.22%
# Validation accuracy: 94.16%
# Validation accuracy character level: 97.40%
# Minibatch loss at step 867500: 0.261793
# Minibatch accuracy: 98.05%
# Validation accuracy: 93.82%
# Validation accuracy character level: 97.35%
# Minibatch loss at step 870000: 0.222316
# Minibatch accuracy: 97.27%
# Validation accuracy: 94.04%
# Validation accuracy character level: 97.38%
# Minibatch loss at step 872500: 0.178060
# Minibatch accuracy: 98.44%
# Validation accuracy: 94.07%
# Validation accuracy character level: 97.38%
# Minibatch loss at step 875000: 0.574380
# Minibatch accuracy: 95.31%
# Validation accuracy: 94.00%
# Validation accuracy character level: 97.38%
# Minibatch loss at step 877500: 0.210486
# Minibatch accuracy: 98.44%
# Validation accuracy: 93.93%
# Validation accuracy character level: 97.33%
# Minibatch loss at step 880000: 0.203583
# Minibatch accuracy: 98.83%
# Validation accuracy: 94.11%
# Validation accuracy character level: 97.39%
# Minibatch loss at step 882500: 0.246459
# Minibatch accuracy: 98.44%
# Validation accuracy: 94.02%
# Validation accuracy character level: 97.39%
# Minibatch loss at step 885000: 0.184531
# Minibatch accuracy: 98.83%
# Validation accuracy: 93.93%
# Validation accuracy character level: 97.36%
# Minibatch loss at step 887500: 0.249311
# Minibatch accuracy: 97.27%
# Validation accuracy: 94.14%
# Validation accuracy character level: 97.40%
# Minibatch loss at step 890000: 0.370145
# Minibatch accuracy: 95.70%
# Validation accuracy: 94.12%
# Validation accuracy character level: 97.37%
# Minibatch loss at step 892500: 0.232166
# Minibatch accuracy: 98.83%
# Validation accuracy: 94.09%
# Validation accuracy character level: 97.40%
# Minibatch loss at step 895000: 0.236737
# Minibatch accuracy: 97.27%
# Validation accuracy: 94.02%
# Validation accuracy character level: 97.34%
# Minibatch loss at step 897500: 0.282907
# Minibatch accuracy: 97.27%
# Validation accuracy: 94.05%
# Validation accuracy character level: 97.38%
# Minibatch loss at step 900000: 0.142134
# Minibatch accuracy: 98.83%
# Validation accuracy: 94.04%
# Validation accuracy character level: 97.36%
# Minibatch loss at step 902500: 0.303536
# Minibatch accuracy: 97.66%
# Validation accuracy: 94.16%
# Validation accuracy character level: 97.41%
# Minibatch loss at step 905000: 0.210133
# Minibatch accuracy: 97.66%
# Validation accuracy: 94.05%
# Validation accuracy character level: 97.42%
# Minibatch loss at step 907500: 0.307771
# Minibatch accuracy: 96.48%
# Validation accuracy: 94.12%
# Validation accuracy character level: 97.42%
# Minibatch loss at step 910000: 0.170912
# Minibatch accuracy: 98.83%
# Validation accuracy: 94.19%
# Validation accuracy character level: 97.45%
# Minibatch loss at step 912500: 0.280650
# Minibatch accuracy: 97.27%
# Validation accuracy: 94.19%
# Validation accuracy character level: 97.41%
# Minibatch loss at step 915000: 0.326019
# Minibatch accuracy: 97.66%
# Validation accuracy: 94.14%
# Validation accuracy character level: 97.42%
# Minibatch loss at step 917500: 0.308618
# Minibatch accuracy: 98.44%
# Validation accuracy: 94.21%
# Validation accuracy character level: 97.43%
# Minibatch loss at step 920000: 0.305676
# Minibatch accuracy: 98.05%
# Validation accuracy: 93.88%
# Validation accuracy character level: 97.37%
# Minibatch loss at step 922500: 0.443871
# Minibatch accuracy: 95.70%
# Validation accuracy: 94.05%
# Validation accuracy character level: 97.38%
# Minibatch loss at step 925000: 0.313243
# Minibatch accuracy: 97.66%
# Validation accuracy: 93.93%
# Validation accuracy character level: 97.37%
# Minibatch loss at step 927500: 0.358664
# Minibatch accuracy: 96.48%
# Validation accuracy: 94.04%
# Validation accuracy character level: 97.39%
# Minibatch loss at step 930000: 0.377676
# Minibatch accuracy: 96.88%
# Validation accuracy: 94.04%
# Validation accuracy character level: 97.36%
# Minibatch loss at step 932500: 0.183031
# Minibatch accuracy: 99.22%
# Validation accuracy: 94.18%
# Validation accuracy character level: 97.43%
# Minibatch loss at step 935000: 0.254195
# Minibatch accuracy: 98.44%
# Validation accuracy: 93.88%
# Validation accuracy character level: 97.34%
# Minibatch loss at step 937500: 0.305420
# Minibatch accuracy: 98.05%
# Validation accuracy: 94.04%
# Validation accuracy character level: 97.37%
# Minibatch loss at step 940000: 0.382292
# Minibatch accuracy: 97.66%
# Validation accuracy: 94.11%
# Validation accuracy character level: 97.38%
# Minibatch loss at step 942500: 0.432021
# Minibatch accuracy: 96.88%
# Validation accuracy: 94.00%
# Validation accuracy character level: 97.38%
# Minibatch loss at step 945000: 0.313090
# Minibatch accuracy: 97.27%
# Validation accuracy: 94.11%
# Validation accuracy character level: 97.39%
# Minibatch loss at step 947500: 0.229004
# Minibatch accuracy: 98.83%
# Validation accuracy: 94.04%
# Validation accuracy character level: 97.38%
# Minibatch loss at step 950000: 0.474598
# Minibatch accuracy: 97.27%
# Validation accuracy: 94.16%
# Validation accuracy character level: 97.42%
# Minibatch loss at step 952500: 0.234451
# Minibatch accuracy: 98.83%
# Validation accuracy: 94.05%
# Validation accuracy character level: 97.39%
# Minibatch loss at step 955000: 0.412990
# Minibatch accuracy: 98.05%
# Validation accuracy: 94.11%
# Validation accuracy character level: 97.39%
# Minibatch loss at step 957500: 0.287996
# Minibatch accuracy: 98.44%
# Validation accuracy: 93.86%
# Validation accuracy character level: 97.34%
# Minibatch loss at step 960000: 0.107163
# Minibatch accuracy: 98.44%
# Validation accuracy: 94.02%
# Validation accuracy character level: 97.39%
# Minibatch loss at step 962500: 0.440319
# Minibatch accuracy: 97.66%
# Validation accuracy: 94.12%
# Validation accuracy character level: 97.43%
# Minibatch loss at step 965000: 0.232600
# Minibatch accuracy: 98.83%
# Validation accuracy: 93.98%
# Validation accuracy character level: 97.37%
# Minibatch loss at step 967500: 0.389957
# Minibatch accuracy: 96.48%
# Validation accuracy: 94.04%
# Validation accuracy character level: 97.36%
# Minibatch loss at step 970000: 0.185129
# Minibatch accuracy: 96.48%
# Validation accuracy: 94.00%
# Validation accuracy character level: 97.39%
# Minibatch loss at step 972500: 0.316752
# Minibatch accuracy: 98.05%
# Validation accuracy: 94.12%
# Validation accuracy character level: 97.42%
# Minibatch loss at step 975000: 0.255468
# Minibatch accuracy: 98.44%
# Validation accuracy: 94.02%
# Validation accuracy character level: 97.37%
# Minibatch loss at step 977500: 0.464193
# Minibatch accuracy: 96.88%
# Validation accuracy: 93.93%
# Validation accuracy character level: 97.38%
# Minibatch loss at step 980000: 0.166775
# Minibatch accuracy: 98.83%
# Validation accuracy: 94.05%
# Validation accuracy character level: 97.40%
# Minibatch loss at step 982500: 0.529102
# Minibatch accuracy: 96.48%
# Validation accuracy: 93.93%
# Validation accuracy character level: 97.39%
# Minibatch loss at step 985000: 0.215573
# Minibatch accuracy: 98.05%
# Validation accuracy: 94.12%
# Validation accuracy character level: 97.43%
# Minibatch loss at step 987500: 0.140684
# Minibatch accuracy: 98.05%
# Validation accuracy: 94.11%
# Validation accuracy character level: 97.41%
# Minibatch loss at step 990000: 0.414721
# Minibatch accuracy: 98.05%
# Validation accuracy: 94.05%
# Validation accuracy character level: 97.42%
# Minibatch loss at step 992500: 0.369086
# Minibatch accuracy: 97.27%
# Validation accuracy: 94.14%
# Validation accuracy character level: 97.45%
# Minibatch loss at step 995000: 0.425875
# Minibatch accuracy: 96.48%
# Validation accuracy: 94.09%
# Validation accuracy character level: 97.40%
# Minibatch loss at step 997500: 0.365490
# Minibatch accuracy: 96.88%
# Validation accuracy: 94.18%
# Validation accuracy character level: 97.42%
# Minibatch loss at step 1000000: 0.253661
# Minibatch accuracy: 96.48%
# Validation accuracy: 93.98%
# Validation accuracy character level: 97.39%
# [ 2  2  2 10 10]    [  2.   2.   2.  10.  10.]    True
# [ 2  1  3 10 10]    [  2.   1.   3.  10.  10.]    True
# [ 2  2  6 10 10]    [  2.   2.   6.  10.  10.]    True
# [ 2  9  4 10 10]    [  2.   9.   4.  10.  10.]    True
# [ 2  4  8 10 10]    [  2.   4.   8.  10.  10.]    True
# [ 2  4  9 10 10]    [  2.   4.   9.  10.  10.]    True
# [ 3  8  2  1 10]    [  3.   8.   2.   1.  10.]    True
# [ 2  4  5 10 10]    [  2.   4.   5.  10.  10.]    True
# [ 1  3 10 10 10]    [  1.   3.  10.  10.  10.]    True
# [ 1  6 10 10 10]    [  1.   6.  10.  10.  10.]    True
# [ 2  5  7 10 10]    [  2.   5.   7.  10.  10.]    True
# [ 2  3  6 10 10]    [  2.   3.   6.  10.  10.]    True
# [ 2  2  2 10 10]    [  2.   2.   2.  10.  10.]    True
# [ 2  2  8 10 10]    [  2.   2.   8.  10.  10.]    True
# [ 2  7  7 10 10]    [  2.   7.   7.  10.  10.]    True
# [ 2  2  0 10 10]    [  2.   2.   0.  10.  10.]    True
# [ 2  1  1 10 10]    [  2.   1.   1.  10.  10.]    True
# [ 2  3  0 10 10]    [  2.   3.   0.  10.  10.]    True
# [ 2  2  8 10 10]    [  2.   2.   8.  10.  10.]    True
# [ 2  2  9 10 10]    [  2.   2.   9.  10.  10.]    True
# [ 2  3  7 10 10]    [  2.   3.   7.  10.  10.]    True
# [ 2  1  2 10 10]    [  2.   1.   2.  10.  10.]    True
# [ 2  2  4 10 10]    [  2.   1.   2.  10.  10.]    False
# [ 2  2  8 10 10]    [  2.   2.   8.  10.  10.]    True
# [ 2  1  8 10 10]    [  2.   1.   8.  10.  10.]    True
# [ 2  4  7 10 10]    [  2.   4.   7.  10.  10.]    True
# [ 1  4 10 10 10]    [  1.   4.  10.  10.  10.]    True
# [ 1  3 10 10 10]    [  1.   3.  10.  10.  10.]    True
# [ 3  1  8  4 10]    [  3.   1.   8.   4.  10.]    True
# [ 2  2  8 10 10]    [  2.   2.   8.  10.  10.]    True
# [ 2  1  4 10 10]    [  2.   1.   4.  10.  10.]    True
# [ 1  7 10 10 10]    [  1.   7.  10.  10.  10.]    True
# [ 2  1  1 10 10]    [  2.   1.   1.  10.  10.]    True
# [ 3  5  4  9 10]    [  3.   5.   4.   9.  10.]    True
# [ 1  5 10 10 10]    [  1.   5.  10.  10.  10.]    True
# [ 2  1  7 10 10]    [  2.   1.   7.  10.  10.]    True
# [ 2  1  4 10 10]    [  2.   1.   4.  10.  10.]    True
# [ 1  7 10 10 10]    [  1.   7.  10.  10.  10.]    True
# [ 2  4  8 10 10]    [  2.   4.   8.  10.  10.]    True
# [ 1  1 10 10 10]    [  1.   1.  10.  10.  10.]    True
# [ 3  3  2  5 10]    [  3.   3.   2.   5.  10.]    True
# [ 1  1 10 10 10]    [  1.   1.  10.  10.  10.]    True
# [ 1  8 10 10 10]    [  1.   8.  10.  10.  10.]    True
# [ 2  2  3 10 10]    [  2.   2.   3.  10.  10.]    True
# [ 2  1  2 10 10]    [  2.   1.   2.  10.  10.]    True
# [ 2  1  2 10 10]    [  2.   1.   2.  10.  10.]    True
# [ 2  4  5 10 10]    [  2.   4.   5.  10.  10.]    True
# [ 1  1 10 10 10]    [  1.   1.  10.  10.  10.]    True
# [ 2  7  7 10 10]    [  2.   7.   7.  10.  10.]    True
# [ 2  4  9 10 10]    [  2.   4.   9.  10.  10.]    True
# [ 2  3  9 10 10]    [  2.   3.   9.  10.  10.]    True
# [ 2  1  2 10 10]    [  2.   1.   2.  10.  10.]    True
# [ 1  8 10 10 10]    [  1.   8.  10.  10.  10.]    True
# [ 2  3  7 10 10]    [  2.   3.   7.  10.  10.]    True
# [ 2  1  6 10 10]    [  2.   1.   6.  10.  10.]    True
# [ 2  2  0 10 10]    [  2.   2.   0.  10.  10.]    True
# [ 2  8  6 10 10]    [  2.   8.   6.  10.  10.]    True
# [ 2  1  5 10 10]    [  3.   1.   5.   1.  10.]    False
# [ 1  5 10 10 10]    [  1.   5.  10.  10.  10.]    True
# [ 2  3  3 10 10]    [  2.   3.   3.  10.  10.]    True
# [ 3  1  0  8 10]    [  3.   1.   0.   8.  10.]    True
# [ 3  2  6  8 10]    [  3.   2.   6.   8.  10.]    True
# [ 2  1  0 10 10]    [  3.   1.   3.   0.  10.]    False
# [ 2  6  3 10 10]    [  2.   6.   3.  10.  10.]    True
# [ 2  4  0 10 10]    [  2.   4.   0.  10.  10.]    True
# [ 2  2  4 10 10]    [  2.   2.   4.  10.  10.]    True
# [ 2  4  8 10 10]    [  2.   4.   8.  10.  10.]    True
# [ 2  1  2 10 10]    [  2.   1.   2.  10.  10.]    True
# [ 2  1  0 10 10]    [  2.   1.   0.  10.  10.]    True
# [ 3  1  5  5 10]    [  3.   1.   5.   5.  10.]    True
# [ 3  2  7  8 10]    [  3.   2.   7.   8.  10.]    True
# [ 3  1  1  0 10]    [  3.   1.   1.   0.  10.]    True
# [ 1  2 10 10 10]    [  1.   2.  10.  10.  10.]    True
# [ 2  5  0 10 10]    [  2.   5.   0.  10.  10.]    True
# [ 2  2  5 10 10]    [  2.   2.   5.  10.  10.]    True
# [ 2  1  8 10 10]    [  2.   1.   8.  10.  10.]    True
# [ 2  7  3 10 10]    [  2.   7.   3.  10.  10.]    True
# [ 3  1  1  2 10]    [  3.   1.   1.   2.  10.]    True
# [ 1  2 10 10 10]    [  1.   2.  10.  10.  10.]    True
# [ 2  3  4 10 10]    [  2.   3.   4.  10.  10.]    True
# [ 2  5  5 10 10]    [  2.   5.   5.  10.  10.]    True
# [ 2  9  2 10 10]    [  2.   9.   2.  10.  10.]    True
# [ 3  1  2  2 10]    [  3.   1.   2.   2.  10.]    True
# [ 2  2  7 10 10]    [  2.   2.   7.  10.  10.]    True
# [ 3  1  4  5 10]    [  3.   1.   4.   5.  10.]    True
# [ 3  2  4  6 10]    [  3.   2.   4.   6.  10.]    True
# [ 2  3  1 10 10]    [  2.   3.   1.  10.  10.]    True
# [ 2  1  8 10 10]    [  2.   1.   8.  10.  10.]    True
# [ 2  1  4 10 10]    [  2.   1.   4.  10.  10.]    True
# [ 2  1  5 10 10]    [  2.   1.   5.  10.  10.]    True
# [ 2  3  9 10 10]    [  2.   3.   9.  10.  10.]    True
# [ 2  8  0 10 10]    [  2.   8.   0.  10.  10.]    True
# [ 2  7  1 10 10]    [  2.   7.   1.  10.  10.]    True
# [ 2  2  2 10 10]    [  2.   2.   2.  10.  10.]    True
# [ 2  2  0 10 10]    [  2.   2.   0.  10.  10.]    True
# [ 2  4  0 10 10]    [  2.   4.   0.  10.  10.]    True
# [ 1  2 10 10 10]    [  1.   2.  10.  10.  10.]    True
# [ 2  5  4 10 10]    [  2.   5.   4.  10.  10.]    True
# [ 2  8  0 10 10]    [  2.   8.   0.  10.  10.]    True
# [ 2  2  9 10 10]    [  2.   2.   9.  10.  10.]    True
# ====> Test accuracy character level: 98.55%
# ====> Test accuracy: 96.00%
# Model saved in file: CNN_multi_deep_ful2_32x32BN.ckpt

# %%
plot_results(acc_train,acc_valid,losses)
